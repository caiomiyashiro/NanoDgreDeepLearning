# %% [markdown]
# ### Turn on autocomplete

# %%
# %config IPCompleter.greedy=True

# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import Dataset

# %%
dataset = pd.read_csv('winequality-red.csv', sep = ';')

# get header names
print(dataset.columns)

# get response variable
y_data = np.matrix(dataset[['quality']])

# remove response variable - 1 is for column drop
dataset = dataset.drop('quality',1)

# convert to matrix
x_data = np.matrix(
            np.column_stack([np.repeat(1, len(dataset)), dataset])
        )
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ### calculate StepGradient based on gradient of the loss function:
#
# $$J(\theta ) = \frac{1}{2m}\sum_{i = 1}^{m}(h_{\theta}(x^{(i)}) - y^{(i)})^2$$
#
# $$\underset{\theta_{0},\theta_{1}}{min}J(\theta_{0}, \theta_{1})$$
#
# #### Update Rule:
# $$\beta _{0} := \beta _{0} - \alpha \frac{\partial }{\partial \beta_{0}}J(\theta_{0}, \theta_{1})$$
#
# $$\beta _{1} := \beta _{1} - \alpha \frac{\partial }{\partial \beta_{1}}J(\theta_{1}, \theta_{1})$$
#
# #### Derivatives
#
# $$\frac{\partial }{\partial \theta_{0}}J(\theta_{0}, \theta_{1}) = \frac{1}{m}\sum_{i = 1}^{m}(h_{\theta}(x^{(i)}) - y^{(i)})$$
#
# $$\frac{\partial }{\partial \theta_{j}}J(\theta_{0}, \theta_{1},...,\theta_{n}) = \frac{1}{m}\sum_{i = 1}^{m}(h_{\theta}(x^{(i)}) - y^{(i)}).x_{j}^{(i)}$$

# %% [markdown]
# ### calculateError - Calculate error based on minimum square error

# %%
def calculateError(predictedValues, y_data):
    # x_data is a MxN matrix
    # y_data is a Mx1 matrix
    # betas is a Nx1 matrix with the regression parameters
    
    m = len(y_data)
    
    error = 1/(2*m) * np.sum(np.power((predictedValues - y_data),2))
    
    return error

# %% [markdown]
# ### calculateStepGradient - Calculate partial derivatives of the cost function on each parameter

# %%
def calculateStepGradient(x_data, y_data, predictedValues):
    # x_data is a MxN matrix
    # y_data is a Mx1 matrix
    # betas is a Nx1 matrix with the regression parameters
    m = len(x_data)
    
    derivativePars = np.zeros((1,x_data.shape[1]))
    nbrBetas = derivativePars.shape[1]
    
    derivativePars[0,0]  = 1/m * np.sum(predictedValues - y_data)
    for i in list(range(1,nbrBetas)): # 1:n
        
        parTemp = 1/m * np.transpose(predictedValues - y_data) * (x_data[:,i])
        derivativePars[0,i] = parTemp.item()
    
    return derivativePars

# %% [markdown]
# ### Define initial call for linear regression

# %%
def linearRegressionRun(x_data, y_data, learningRate = 0.0001, maxNbrIteractions = 1000, errorConvergence = 0.0001):
    # model parameters
    # learningRate - The amount of variation the gradient will provoke in the delta of the weights
    # maxNbrIteractions - Max number of iteractions for the batch gradient descent
    # errorConvergence - if next iteraction doesn't improve on the limit, stop
    betas = np.zeros(shape = (x_data.shape[1], 1))
    
    errorArray = np.zeros(maxNbrIteractions) # store error
    calcErrorConvergence = 10                # random number
    i = 0                                    # count
    while( i < maxNbrIteractions and calcErrorConvergence > errorConvergence):
        
        predictedValues = np.matrix(x_data * betas)
        
        errorArray[i] = calculateError(predictedValues, y_data)
        print('Cost in iteraction ' + str(i) + ': ' + str(errorArray[i]))
        if(i >= 1): # calculate error convergence starting from index 1
            calcErrorConvergence = abs(errorArray[i] - errorArray[i-1])
            print('Error convergence: ' + str(calcErrorConvergence))
        
        betasGradient = calculateStepGradient(x_data, y_data, predictedValues)        
        print('Derivatives: ' + str(betasGradient))

        # multiply matrix times scalar
        learnedGradient = np.multiply(learningRate,betasGradient).transpose()
        betas = np.subtract(betas,learnedGradient)
        
        print('New betas: \n' + str(betas))
        print('\n')
        
        i = i + 1
    return (betas, errorArray)

# %% [markdown]
# ### Call Function

# %%
(betas, errorArray) = linearRegressionRun(x_data, y_data,learningRate = 0.0001)

# trying to run (betas, errorArray) = linearRegressionRun(x_data, y_data, learningRate = 0.001)
# explode the gradient and the error just keep increasing
# Out:
# Cost in iteraction 0: 16.2082551595
# Derivatives: [[  -5.63602251  -47.06397749   -2.91836773   -1.56281426  -14.32439024
#     -0.48806692  -89.04377736 -256.9793621    -5.61742029  -18.6543152
#     -3.74373358  -59.15370023]]
# New betas:
# [[  5.63602251e-04]
#  [  4.70639775e-03]
#  [  2.91836773e-04]
#  [  1.56281426e-04]
#  [  1.43243902e-03]
#  [  4.88066917e-05]
#  [  8.90437774e-03]
#  [  2.56979362e-02]
#  [  5.61742029e-04]
#  [  1.86543152e-03]
#  [  3.74373358e-04]
#  [  5.91537002e-03]]
#
#
# Cost in iteraction 1: 9.63617435327
# Error convergence: 6.5720808062
# Derivatives: [[  -4.18834462  -35.19754922   -2.1434485    -1.16455004  -10.37812004
#     -0.35956055  -59.20183173 -159.93416439   -4.17433674  -13.86919965
#     -2.78362443  -44.25028471]]
# New betas:
# [[  9.82436714e-04]
#  [  8.22615267e-03]
#  [  5.06181623e-04]
#  [  2.72736430e-04]
#  [  2.47025103e-03]
#  [  8.47627471e-05]
#  [  1.48245609e-02]
#  [  4.16913526e-02]
#  [  9.79175703e-04]
#  [  3.25235148e-03]
#  [  6.52735801e-04]
#  [  1.03403985e-02]]
#
#
# Cost in iteraction 2: 6.95850698767
# Error convergence: 2.67766736561
# Derivatives: [[ -3.26738534 -27.64546309  -1.65070399  -0.91116444  -7.86984321
#    -0.2778379  -40.27258258 -98.52948245  -3.25630129 -10.82500887
#    -2.17286006 -34.76621803]]
# New betas:
# [[ 0.00130918]
#  [ 0.0109907 ]
#  [ 0.00067125]
#  [ 0.00036385]
#  [ 0.00325724]
#  [ 0.00011255]
#  [ 0.01885182]
#  [ 0.0515443 ]
#  [ 0.00130481]
#  [ 0.00433485]
#  [ 0.00087002]
#  [ 0.01381702]]
#
#
# Cost in iteraction 3: 5.8420460319
# Error convergence: 1.11646095576
# Derivatives: [[ -2.67988053 -22.82471857  -1.33659633  -0.74949827  -6.27191264
#    -0.22573278 -28.25157583 -59.68533344  -2.67066274  -8.88296195
#    -1.78325839 -28.71305305]]
# New betas:
# [[ 0.00157716]
#  [ 0.01327317]
#  [ 0.00080491]
#  [ 0.0004388 ]
#  [ 0.00388443]
#  [ 0.00013512]
#  [ 0.02167698]
#  [ 0.05751283]
#  [ 0.00157187]
#  [ 0.00522315]
#  [ 0.00104835]
#  [ 0.01668833]]
#
#
# Cost in iteraction 4: 5.3518623112
# Error convergence: 0.490183720706
# Derivatives: [[ -2.30349196 -19.73325925  -1.13558497  -0.64590121  -5.25032226
#    -0.19237882 -20.60395193 -35.12197193  -2.29547084  -7.63870374
#    -1.5336788  -24.83208128]]
# New betas:
# [[ 0.00180751]
#  [ 0.0152465 ]
#  [ 0.00091847]
#  [ 0.00050339]
#  [ 0.00440946]
#  [ 0.00015436]
#  [ 0.02373737]
#  [ 0.06102503]
#  [ 0.00180142]
#  [ 0.00598702]
#  [ 0.00120172]
#  [ 0.01917153]]
#
#
# Cost in iteraction 5: 5.11331743739
# Error convergence: 0.238544873803
# Derivatives: [[ -2.06077807 -17.73677168  -1.00618198  -0.57907224  -4.59364248
#    -0.17089749 -15.72511802 -19.59824627  -2.05352965  -6.83627274
#    -1.37275832 -22.32652547]]
# New betas:
# [[ 0.00201359]
#  [ 0.01702017]
#  [ 0.00101909]
#  [ 0.0005613 ]
#  [ 0.00486882]
#  [ 0.00017145]
#  [ 0.02530988]
#  [ 0.06298486]
#  [ 0.00200677]
#  [ 0.00667065]
#  [ 0.00133899]
#  [ 0.02140419]]
#
#
# Cost in iteraction 6: 4.97628200244
# Error convergence: 0.137035434951
# Derivatives: [[ -1.90271739 -16.433727    -0.922125    -0.53552751  -4.16803575
#    -0.15693458 -12.59934846  -9.79646209  -1.89597316  -6.31364198
#    -1.26798354 -20.69201503]]
# New betas:
# [[ 0.00220386]
#  [ 0.01866355]
#  [ 0.0011113 ]
#  [ 0.00061485]
#  [ 0.00528563]
#  [ 0.00018714]
#  [ 0.02656982]
#  [ 0.0639645 ]
#  [ 0.00219637]
#  [ 0.00730201]
#  [ 0.00146579]
#  [ 0.02347339]]
#
#
# Cost in iteraction 7: 4.88058765097
# Error convergence: 0.0956943514691
# Derivatives: [[ -1.79827855 -15.56995116  -0.86678956  -0.50673156  -3.88878102
#    -0.14773382 -10.58367596  -3.61649093  -1.79186842  -5.96824592
#    -1.19877297 -19.60927546]]
# New betas:
# [[ 0.00238369]
#  [ 0.02022054]
#  [ 0.00119798]
#  [ 0.00066553]
#  [ 0.0056745 ]
#  [ 0.00020191]
#  [ 0.02762819]
#  [ 0.06432615]
#  [ 0.00237556]
#  [ 0.00789884]
#  [ 0.00158567]
#  [ 0.02543432]]
#
#
# Cost in iteraction 8: 4.80211366056
# Error convergence: 0.0784739904168
# Derivatives: [[ -1.72781812 -14.98454704  -0.82965209  -0.48728128  -3.7022484
#    -0.14155044  -9.27109268   0.2710655   -1.72163429  -5.73515862
#    -1.15209815 -18.87619981]]
# New betas:
# [[ 0.00255647]
#  [ 0.021719  ]
#  [ 0.00128095]
#  [ 0.00071425]
#  [ 0.00604473]
#  [ 0.00021607]
#  [ 0.0285553 ]
#  [ 0.06429904]
#  [ 0.00254772]
#  [ 0.00847235]
#  [ 0.00170088]
#  [ 0.02732194]]
#
#
# Cost in iteraction 9: 4.73118380623
# Error convergence: 0.070929854331
# Derivatives: [[ -1.67890133 -14.57566272  -0.80405091  -0.47375637  -3.57448901
#    -0.13727996  -8.40395526   2.70772629  -1.67287546  -5.57328039
#    -1.11971173 -18.36484926]]
# New betas:
# [[ 0.00272436]
#  [ 0.02317656]
#  [ 0.00136135]
#  [ 0.00076163]
#  [ 0.00640218]
#  [ 0.0002298 ]
#  [ 0.02939569]
#  [ 0.06402827]
#  [ 0.00271501]
#  [ 0.00902968]
#  [ 0.00181285]
#  [ 0.02915842]]
#
#
# Cost in iteraction 10: 4.66390997078
# Error convergence: 0.0672738354481
# Derivatives: [[ -1.64365658 -14.27882239  -0.785769    -0.46399168  -3.48401222
#    -0.13422322  -7.81916946   4.22617864  -1.63774527  -5.45659376
#    -1.09639288 -17.99423411]]
# New betas:
# [[ 0.00288873]
#  [ 0.02460444]
#  [ 0.00143993]
#  [ 0.00080803]
#  [ 0.00675058]
#  [ 0.00024322]
#  [ 0.03017761]
#  [ 0.06360565]
#  [ 0.00287878]
#  [ 0.00957534]
#  [ 0.00192249]
#  [ 0.03095784]]
#
#
# Cost in iteraction 11: 4.5987235221
# Error convergence: 0.0651864486745
# Derivatives: [[ -1.61710075 -14.05320974  -0.77213679  -0.45661657  -3.41721361
#    -0.1319376   -7.41349149   5.16361636  -1.61127642  -5.36862846
#    -1.07883658 -17.71308394]]
# New betas:
# [[ 0.00305044]
#  [ 0.02600977]
#  [ 0.00151714]
#  [ 0.00085369]
#  [ 0.0070923 ]
#  [ 0.00025641]
#  [ 0.03091896]
#  [ 0.06308929]
#  [ 0.00303991]
#  [ 0.0101122 ]
#  [ 0.00203037]
#  [ 0.03272915]]
#
#
# Cost in iteraction 12: 4.5349854312
# Error convergence: 0.0637380909006
# Derivatives: [[ -1.59607922 -13.87298513  -0.76146429  -0.45076333  -3.36548079
#    -0.1301429   -7.12156351   5.73348419  -1.59032429  -5.29895769
#    -1.06495053 -17.48894089]]
# New betas:
# [[ 0.00321005]
#  [ 0.02739706]
#  [ 0.00159329]
#  [ 0.00089877]
#  [ 0.00742885]
#  [ 0.00026943]
#  [ 0.03163111]
#  [ 0.06251594]
#  [ 0.00319894]
#  [ 0.0106421 ]
#  [ 0.00213687]
#  [ 0.03447805]]
#
#
# Cost in iteraction 13: 4.47242934261
# Error convergence: 0.0625560885966
# Derivatives: [[ -1.57859479 -13.72178929  -0.75268157  -0.44588262  -3.32336138
#    -0.12866175  -6.90200986   6.07089263  -1.572898    -5.24098023
#    -1.05341008 -17.30125568]]
# New betas:
# [[ 0.0033679 ]
#  [ 0.02876924]
#  [ 0.00166856]
#  [ 0.00094336]
#  [ 0.00776119]
#  [ 0.00028229]
#  [ 0.03232131]
#  [ 0.06190885]
#  [ 0.00335623]
#  [ 0.01116619]
#  [ 0.00224221]
#  [ 0.03620817]]
#
#
# Cost in iteraction 14: 4.41093840926
# Error convergence: 0.0614909333452
# Derivatives: [[ -1.56338291 -13.58926417  -0.74511123  -0.44162663  -3.28740333
#    -0.12738182  -6.7286358    6.26136591  -1.55773703  -5.19051649
#    -1.04337653 -17.13701727]]
# New betas:
# [[ 0.00352424]
#  [ 0.03012817]
#  [ 0.00174307]
#  [ 0.00098752]
#  [ 0.00808993]
#  [ 0.00029503]
#  [ 0.03299418]
#  [ 0.06128272]
#  [ 0.00351201]
#  [ 0.01168525]
#  [ 0.00234654]
#  [ 0.03792187]]
#
#
# Cost in iteraction 15: 4.35045586705
# Error convergence: 0.0604825422107
# Derivatives: [[ -1.54964285 -13.46885055  -0.73832433  -0.43777511  -3.25542083
#    -0.126232    -6.58485636   6.35903968  -1.54404319  -5.1449198
#    -1.03431881 -16.98798646]]
# New betas:
# [[ 0.00367921]
#  [ 0.03147505]
#  [ 0.0018169 ]
#  [ 0.0010313 ]
#  [ 0.00841547]
#  [ 0.00030766]
#  [ 0.03365266]
#  [ 0.06064681]
#  [ 0.00366641]
#  [ 0.01219974]
#  [ 0.00244998]
#  [ 0.03962067]]
#
#
# Cost in iteraction 16: 4.2909491989
# Error convergence: 0.0595066681524
# Derivatives: [[ -1.53686744 -13.35639393  -0.73204922  -0.43418857  -3.22602957
#    -0.12516724  -6.46016959   6.39818041  -1.53131091  -5.10251388
#    -1.02590053 -16.84894464]]
# New betas:
# [[ 0.00383289]
#  [ 0.03281069]
#  [ 0.0018901 ]
#  [ 0.00107471]
#  [ 0.00873807]
#  [ 0.00032017]
#  [ 0.03429868]
#  [ 0.060007  ]
#  [ 0.00381954]
#  [ 0.01270999]
#  [ 0.00255257]
#  [ 0.04130557]]
#
#
# Cost in iteraction 17: 4.2323957723
# Error convergence: 0.0585534265987
# Derivatives: [[ -1.52473538 -13.24926203  -0.72611379  -0.43077863  -3.19835266
#    -0.12415901  -6.34792425   6.40047717  -1.51921991  -5.06223668
#    -1.0179086  -16.71658534]]
# New betas:
# [[ 0.00398537]
#  [ 0.03413562]
#  [ 0.00196272]
#  [ 0.00111779]
#  [ 0.00905791]
#  [ 0.00033259]
#  [ 0.03493347]
#  [ 0.05936695]
#  [ 0.00397146]
#  [ 0.01321621]
#  [ 0.00265436]
#  [ 0.04297723]]
#
#
# Cost in iteraction 18: 4.17477708132
# Error convergence: 0.0576186909823
# Derivatives: [[ -1.51304299 -13.14578619  -0.72040897  -0.42748929  -3.17183438
#    -0.12318923  -6.24390663   6.37965749  -1.50756716  -5.02341499
#    -1.01020792 -16.58881249]]
# New betas:
# [[ 0.00413667]
#  [ 0.0354502 ]
#  [ 0.00203476]
#  [ 0.00116054]
#  [ 0.00937509]
#  [ 0.00034491]
#  [ 0.03555786]
#  [ 0.05872898]
#  [ 0.00412222]
#  [ 0.01371856]
#  [ 0.00275538]
#  [ 0.04463611]]
#
#
# Cost in iteraction 19: 4.11807643644
# Error convergence: 0.0567006448751
# Derivatives: [[ -1.50166106 -13.04490772  -0.71486561  -0.42428501  -3.14612235
#    -0.12224643  -6.14544604   6.34440912  -1.49622387  -4.98562177
#    -1.00271281 -16.46429625]]
# New betas:
# [[ 0.00428684]
#  [ 0.03675469]
#  [ 0.00210624]
#  [ 0.00120297]
#  [ 0.0096897 ]
#  [ 0.00035713]
#  [ 0.03617241]
#  [ 0.05809454]
#  [ 0.00427184]
#  [ 0.01421712]
#  [ 0.00285565]
#  [ 0.04628254]]
#
#
# Cost in iteraction 20: 4.06227803607
# Error convergence: 0.055798400376
# Derivatives: [[ -1.49050756 -12.9459541   -0.70943977  -0.42114323  -3.12099288
#    -0.12132331  -6.05084854   6.30022966  -1.48510824  -4.94858577
#    -0.99536885 -16.34219183]]
# New betas:
# [[ 0.00443589]
#  [ 0.03804929]
#  [ 0.00217719]
#  [ 0.00124508]
#  [ 0.0100018 ]
#  [ 0.00036926]
#  [ 0.03677749]
#  [ 0.05746452]
#  [ 0.00442035]
#  [ 0.01471198]
#  [ 0.00295519]
#  [ 0.04791676]]
#
#
# Cost in iteraction 21: 4.00736659162
# Error convergence: 0.0549114444478
# Derivatives: [[ -1.47953026 -12.84849726  -0.70410353  -0.4180496   -3.09630376
#    -0.12041526  -5.95903856   6.25059731  -1.47416823  -4.9121344
#    -0.98814141 -16.22196152]]
# New betas:
# [[ 0.00458384]
#  [ 0.03933413]
#  [ 0.0022476 ]
#  [ 0.00128689]
#  [ 0.01031143]
#  [ 0.00038131]
#  [ 0.0373734 ]
#  [ 0.05683946]
#  [ 0.00456777]
#  [ 0.01520319]
#  [ 0.003054  ]
#  [ 0.04953895]]
#
#
# Cost in iteraction 22: 3.9533271746
# Error convergence: 0.0540394170147
# Derivatives: [[ -1.46869584 -12.7522639   -0.69883908  -0.41499495  -3.07196436
#    -0.11951931  -5.86933197   6.19771199  -1.46337063  -4.87615752
#    -0.9810084  -16.10326199]]
# New betas:
# [[ 0.00473071]
#  [ 0.04060936]
#  [ 0.00231748]
#  [ 0.00132839]
#  [ 0.01061863]
#  [ 0.00039326]
#  [ 0.03796033]
#  [ 0.05621969]
#  [ 0.00471411]
#  [ 0.01569081]
#  [ 0.0031521 ]
#  [ 0.05114928]]
#
#
# Cost in iteraction 23: 3.90014515261
# Error convergence: 0.0531820219971
# Derivatives: [[ -1.45798297 -12.6570787   -0.69363503  -0.41197344  -3.04791672
#    -0.11863358  -5.78129244   6.14296446  -1.45269416  -4.84058453
#    -0.97395566 -15.98587302]]
# New betas:
# [[ 0.00487651]
#  [ 0.04187507]
#  [ 0.00238684]
#  [ 0.00136959]
#  [ 0.01092342]
#  [ 0.00040512]
#  [ 0.03853846]
#  [ 0.05560539]
#  [ 0.00485938]
#  [ 0.01617486]
#  [ 0.0032495 ]
#  [ 0.05274786]]
#
#
# Cost in iteraction 24: 3.84780616099
# Error convergence: 0.0523389916161
# Derivatives: [[ -1.44737784 -12.5628284   -0.68848404  -0.40898126  -3.02412355
#    -0.11775684  -5.69464056   6.08723332  -1.44212507  -4.80536987
#    -0.96697405 -15.86965232]]
# New betas:
# [[ 0.00502125]
#  [ 0.04313135]
#  [ 0.00245569]
#  [ 0.00141048]
#  [ 0.01122583]
#  [ 0.0004169 ]
#  [ 0.03910792]
#  [ 0.05499667]
#  [ 0.00500359]
#  [ 0.0166554 ]
#  [ 0.00334619]
#  [ 0.05433483]]
#
#
# Cost in iteraction 25: 3.79629608895
# Error convergence: 0.0515100720428
# Derivatives: [[ -1.43687149 -12.46943902  -0.68338133  -0.40601596  -3.00056065
#    -0.1168883   -5.60919625   6.03107296  -1.43165442  -4.77048381
#    -0.96005762 -15.75450696]]
# New betas:
# [[ 0.00516493]
#  [ 0.0443783 ]
#  [ 0.00252403]
#  [ 0.00145109]
#  [ 0.01152589]
#  [ 0.00042859]
#  [ 0.03966884]
#  [ 0.05439356]
#  [ 0.00514675]
#  [ 0.01713245]
#  [ 0.0034422 ]
#  [ 0.05591028]]
#
#
# Cost in iteraction 26: 3.74560107135
# Error convergence: 0.0506950176024
# Derivatives: [[ -1.42645797 -12.37686148  -0.67832376  -0.4030759   -2.97721212
#    -0.11602745  -5.52484237   5.97483257  -1.42127627  -4.7359067
#    -0.95320242 -15.64037529]]
# New betas:
# [[ 0.00530758]
#  [ 0.04561598]
#  [ 0.00259186]
#  [ 0.00149139]
#  [ 0.01182361]
#  [ 0.00044019]
#  [ 0.04022133]
#  [ 0.05379608]
#  [ 0.00528888]
#  [ 0.01760604]
#  [ 0.00353752]
#  [ 0.05747432]]
#
#
# Cost in iteraction 27: 3.69570748294
# Error convergence: 0.0498935884063
# Derivatives: [[ -1.41613326 -12.28506248  -0.67330922  -0.40016     -2.95406732
#    -0.11517392  -5.44150163   5.91873145  -1.41098664  -4.70162524
#    -0.9464058  -15.52721547]]
# New betas:
# [[ 0.00544919]
#  [ 0.04684449]
#  [ 0.00265919]
#  [ 0.00153141]
#  [ 0.01211902]
#  [ 0.00045171]
#  [ 0.04076548]
#  [ 0.0532042 ]
#  [ 0.00542998]
#  [ 0.0180762 ]
#  [ 0.00363216]
#  [ 0.05902704]]
#
#
# Cost in iteraction 28: 3.64660193358
# Error convergence: 0.0491055493589
# Derivatives: [[ -1.40589457 -12.19401873  -0.66833625  -0.39726749  -2.93111892
#    -0.11432748  -5.35912198   5.86290671  -1.40078272  -4.66763016
#    -0.9396659  -15.41499822]]
# New betas:
# [[ 0.00558978]
#  [ 0.04806389]
#  [ 0.00272603]
#  [ 0.00157114]
#  [ 0.01241213]
#  [ 0.00046314]
#  [ 0.04130139]
#  [ 0.05261791]
#  [ 0.00557006]
#  [ 0.01854297]
#  [ 0.00372613]
#  [ 0.06056854]]
#
#
# Cost in iteraction 29: 3.59827126386
# Error convergence: 0.0483306697161
# Derivatives: [[ -1.39573988 -12.10371328  -0.66340381  -0.39439782  -2.90836173
#    -0.11348795  -5.27766742   5.80744343  -1.3906625   -4.63391476
#    -0.93298138 -15.30370226]]
# New betas:
# [[ 0.00572936]
#  [ 0.04927426]
#  [ 0.00279237]
#  [ 0.00161058]
#  [ 0.01270296]
#  [ 0.00047449]
#  [ 0.04182916]
#  [ 0.05203717]
#  [ 0.00570912]
#  [ 0.01900636]
#  [ 0.00381943]
#  [ 0.06209891]]
#
#
# Cost in iteraction 30: 3.550702541
# Error convergence: 0.0475687228656
# Derivatives: [[ -1.38566765 -12.01413325  -0.65851112  -0.39155058  -2.88579189
#    -0.1126552   -5.1971121    5.7523938   -1.38062447  -4.60047397
#    -0.92635124 -15.19331137]]
# New betas:
# [[ 0.00586792]
#  [ 0.05047567]
#  [ 0.00285822]
#  [ 0.00164973]
#  [ 0.01299154]
#  [ 0.00048575]
#  [ 0.04234887]
#  [ 0.05146193]
#  [ 0.00584719]
#  [ 0.0194664 ]
#  [ 0.00391206]
#  [ 0.06361824]]
#
#
# Cost in iteraction 31: 3.5038830548
# Error convergence: 0.0468194861965
# Derivatives: [[ -1.37567668 -11.9252683   -0.65365756  -0.38872543  -2.8634064
#    -0.11182912  -5.11743663   5.69778915  -1.37066741  -4.56730375
#    -0.91977467 -15.0838126 ]]
# New betas:
# [[ 0.00600549]
#  [ 0.0516682 ]
#  [ 0.00292359]
#  [ 0.0016886 ]
#  [ 0.01327788]
#  [ 0.00049694]
#  [ 0.04286061]
#  [ 0.05089215]
#  [ 0.00598425]
#  [ 0.01992313]
#  [ 0.00400404]
#  [ 0.06512662]]
#
#
# Cost in iteraction 32: 3.4578003138
# Error convergence: 0.046082741006
# Derivatives: [[ -1.36576595 -11.83710975  -0.64884265  -0.38592211  -2.84120281
#    -0.11100964  -5.03862575   5.64364769  -1.36079032  -4.53440075
#    -0.91325101 -14.97519502]]
# New betas:
# [[ 0.00614207]
#  [ 0.05285191]
#  [ 0.00298847]
#  [ 0.0017272 ]
#  [ 0.013562  ]
#  [ 0.00050804]
#  [ 0.04336447]
#  [ 0.05032779]
#  [ 0.00612033]
#  [ 0.02037657]
#  [ 0.00409536]
#  [ 0.06662414]]
#
#
# Cost in iteraction 33: 3.41244204138
# Error convergence: 0.0453582724212
# Derivatives: [[ -1.35593457 -11.74965001  -0.64406593  -0.38314038  -2.81917899
#    -0.11019667  -4.96066684   5.5899793   -1.35099231  -4.50176202
#    -0.90677966 -14.86744908]]
# New betas:
# [[ 0.00627766]
#  [ 0.05402688]
#  [ 0.00305288]
#  [ 0.00176551]
#  [ 0.01384392]
#  [ 0.00051906]
#  [ 0.04386054]
#  [ 0.04976879]
#  [ 0.00625543]
#  [ 0.02082675]
#  [ 0.00418604]
#  [ 0.06811089]]
#
#
# Cost in iteraction 34: 3.36779617205
# Error convergence: 0.0446458693279
# Derivatives: [[ -1.34618176 -11.66288215  -0.63932702  -0.38038003  -2.79733308
#    -0.10939016  -4.88354895   5.53678858  -1.34127258  -4.46938489
#    -0.9003601  -14.76056608]]
# New betas:
# [[ 0.00641228]
#  [ 0.05519317]
#  [ 0.00311681]
#  [ 0.00180355]
#  [ 0.01412366]
#  [ 0.00052999]
#  [ 0.0443489 ]
#  [ 0.04921511]
#  [ 0.00638956]
#  [ 0.02127369]
#  [ 0.00427608]
#  [ 0.06958694]]
#
#
# Cost in iteraction 35: 3.32385084774
# Error convergence: 0.043945324303
# Derivatives: [[ -1.33650676 -11.57679971  -0.63462556  -0.37764086  -2.77566335
#    -0.10859003  -4.80726226   5.48407687  -1.3316304   -4.4372669
#    -0.89399185 -14.65453789]]
# New betas:
# [[ 0.00654593]
#  [ 0.05635085]
#  [ 0.00318027]
#  [ 0.00184131]
#  [ 0.01440122]
#  [ 0.00054085]
#  [ 0.04482962]
#  [ 0.0486667 ]
#  [ 0.00652272]
#  [ 0.02171742]
#  [ 0.00436548]
#  [ 0.0710524 ]]
#
#
# Cost in iteraction 36: 3.2805944142
# Error convergence: 0.0432564335488
# Derivatives: [[ -1.32690888 -11.49139652  -0.62996121  -0.37492268  -2.75416816
#    -0.10779624  -4.73179767   5.43184339  -1.32206507  -4.40540567
#    -0.88767443 -14.54935678]]
# New betas:
# [[ 0.00667862]
#  [ 0.05749999]
#  [ 0.00324327]
#  [ 0.0018788 ]
#  [ 0.01467664]
#  [ 0.00055163]
#  [ 0.0453028 ]
#  [ 0.04812352]
#  [ 0.00665493]
#  [ 0.02215796]
#  [ 0.00445424]
#  [ 0.07250733]]
#
#
# Cost in iteraction 37: 3.23801541737
# Error convergence: 0.0425789968287
# Derivatives: [[ -1.31738741 -11.40666665  -0.62533364  -0.37222531  -2.73284595
#    -0.10700872  -4.65714654   5.38008608  -1.31257589  -4.37379894
#    -0.88140739 -14.44501526]]
# New betas:
# [[ 0.00681036]
#  [ 0.05864065]
#  [ 0.0033058 ]
#  [ 0.00191603]
#  [ 0.01494992]
#  [ 0.00056233]
#  [ 0.04576852]
#  [ 0.04758551]
#  [ 0.00678619]
#  [ 0.02259534]
#  [ 0.00454238]
#  [ 0.07395183]]
#
#
# Cost in iteraction 38: 3.19610259996
# Error convergence: 0.0419128174048
# Derivatives: [[ -1.30794172 -11.32260429  -0.62074253  -0.36954857  -2.71169519
#    -0.10622743  -4.58330059   5.32880205  -1.30316222  -4.3424445
#    -0.8751903  -14.34150605]]
# New betas:
# [[ 0.00694115]
#  [ 0.05977291]
#  [ 0.00336787]
#  [ 0.00195298]
#  [ 0.01522109]
#  [ 0.00057296]
#  [ 0.04622685]
#  [ 0.04705263]
#  [ 0.0069165 ]
#  [ 0.02302958]
#  [ 0.0046299 ]
#  [ 0.07538598]]
#
#
# Cost in iteraction 39: 3.15484489799
# Error convergence: 0.0412577019757
# Derivatives: [[ -1.29857113 -11.23920378  -0.61618756  -0.36689229  -2.69071441
#    -0.1054523   -4.51025176   5.27798794  -1.2938234   -4.31134017
#    -0.86902272 -14.23882202]]
# New betas:
# [[ 0.00707101]
#  [ 0.06089683]
#  [ 0.00342949]
#  [ 0.00198967]
#  [ 0.01549016]
#  [ 0.0005835 ]
#  [ 0.04667787]
#  [ 0.04652483]
#  [ 0.00704589]
#  [ 0.02346071]
#  [ 0.00471681]
#  [ 0.07680987]]
#
#
# Cost in iteraction 40: 3.11423143737
# Error convergence: 0.0406134606163
# Derivatives: [[ -1.28927502 -11.15645951  -0.61166844  -0.36425631  -2.66990215
#    -0.10468329  -4.43799218   5.22764005  -1.28455879  -4.28048384
#    -0.86290424 -14.13695613]]
# New betas:
# [[ 0.00719994]
#  [ 0.06201248]
#  [ 0.00349066]
#  [ 0.0020261 ]
#  [ 0.01575715]
#  [ 0.00059397]
#  [ 0.04712167]
#  [ 0.04600207]
#  [ 0.00717434]
#  [ 0.02388876]
#  [ 0.0048031 ]
#  [ 0.07822356]]
#
#
# Cost in iteraction 41: 3.07425153065
# Error convergence: 0.0399799067183
# Derivatives: [[ -1.28005276 -11.07436596  -0.60718486  -0.36164044  -2.64925696
#    -0.10392034  -4.36651412   5.17775455  -1.27536778  -4.24987338
#    -0.85683444 -14.03590146]]
# New betas:
# [[ 0.00732794]
#  [ 0.06311992]
#  [ 0.00355138]
#  [ 0.00206226]
#  [ 0.01602208]
#  [ 0.00060436]
#  [ 0.04755832]
#  [ 0.04548429]
#  [ 0.00730188]
#  [ 0.02431375]
#  [ 0.00488878]
#  [ 0.07962715]]
#
#
# Cost in iteraction 42: 3.03489467372
# Error convergence: 0.0393568569316
# Derivatives: [[ -1.27090371 -10.99291769  -0.60273652  -0.35904453  -2.62877744
#    -0.10316341  -4.29580993   5.12832747  -1.26624973  -4.21950673
#    -0.85081291 -13.93565114]]
# New betas:
# [[ 0.00745503]
#  [ 0.06421921]
#  [ 0.00361165]
#  [ 0.00209816]
#  [ 0.01628496]
#  [ 0.00061468]
#  [ 0.0479879 ]
#  [ 0.04497146]
#  [ 0.0074285 ]
#  [ 0.0247357 ]
#  [ 0.00497386]
#  [ 0.08102072]]
#
#
# Cost in iteraction 43: 2.99615054261
# Error convergence: 0.0387441311071
# Derivatives: [[ -1.26182727 -10.9121093   -0.59832313  -0.35646842  -2.60846217
#    -0.10241244  -4.2258721    5.0793548   -1.25720403  -4.18938182
#    -0.84483924 -13.83619839]]
# New betas:
# [[ 0.00758122]
#  [ 0.06531042]
#  [ 0.00367148]
#  [ 0.00213381]
#  [ 0.0165458 ]
#  [ 0.00062492]
#  [ 0.04841049]
#  [ 0.04446352]
#  [ 0.00755422]
#  [ 0.02515464]
#  [ 0.00505835]
#  [ 0.08240434]]
#
#
# Cost in iteraction 44: 2.95800899037
# Error convergence: 0.03814155224
# Derivatives: [[ -1.25282283 -10.83193544  -0.59394439  -0.35391194  -2.58830978
#    -0.10166738  -4.15669317   5.03083254  -1.24823008  -4.15949662
#    -0.83891303 -13.7375365 ]]
# New betas:
# [[ 0.0077065 ]
#  [ 0.06639361]
#  [ 0.00373088]
#  [ 0.0021692 ]
#  [ 0.01680463]
#  [ 0.00063509]
#  [ 0.04882616]
#  [ 0.04396044]
#  [ 0.00767905]
#  [ 0.02557059]
#  [ 0.00514224]
#  [ 0.08377809]]
#
#
# Cost in iteraction 45: 2.92046004396
# Error convergence: 0.037548946415
# Derivatives: [[ -1.24388977 -10.75239082  -0.58960002  -0.35137492  -2.56831888
#    -0.10092819  -4.08826578   4.98275666  -1.23932727  -4.12984912
#    -0.83303388 -13.63965882]]
# New betas:
# [[ 0.00783089]
#  [ 0.06746885]
#  [ 0.00378984]
#  [ 0.00220434]
#  [ 0.01706147]
#  [ 0.00064518]
#  [ 0.04923499]
#  [ 0.04346216]
#  [ 0.00780298]
#  [ 0.02598357]
#  [ 0.00522554]
#  [ 0.08514206]]
#
#
# Cost in iteraction 46: 2.88349390121
# Error convergence: 0.0369661427513
# Derivatives: [[ -1.2350275  -10.67347019  -0.58528973  -0.34885722  -2.54848811
#    -0.10019481  -4.02058264   4.93512316  -1.23049501  -4.10043731
#    -0.82720139 -13.54255874]]
# New betas:
# [[ 0.00795439]
#  [ 0.0685362 ]
#  [ 0.00384837]
#  [ 0.00223923]
#  [ 0.01731632]
#  [ 0.0006552 ]
#  [ 0.04963704]
#  [ 0.04296865]
#  [ 0.00792603]
#  [ 0.02639362]
#  [ 0.00530826]
#  [ 0.08649631]]
#
#
# Cost in iteraction 47: 2.84710092786
# Error convergence: 0.0363929733496
# Derivatives: [[ -1.22623543 -10.59516836  -0.58101323  -0.34635867  -2.52881612
#    -0.0994672   -3.95363653   4.88792805  -1.22173269  -4.07125921
#    -0.82141517 -13.44622975]]
# New betas:
# [[ 0.00807702]
#  [ 0.06959571]
#  [ 0.00390647]
#  [ 0.00227386]
#  [ 0.0175692 ]
#  [ 0.00066515]
#  [ 0.05003241]
#  [ 0.04247986]
#  [ 0.0080482 ]
#  [ 0.02680074]
#  [ 0.0053904 ]
#  [ 0.08784094]]
#
#
# Cost in iteraction 48: 2.81127165462
# Error convergence: 0.0358292732393
# Derivatives: [[ -1.21751297 -10.51748016  -0.57677024  -0.34387912  -2.50930157
#    -0.0987453   -3.88742031   4.84116739  -1.21303975  -4.04231286
#    -0.81567484 -13.35066536]]
# New betas:
# [[ 0.00819877]
#  [ 0.07064746]
#  [ 0.00396415]
#  [ 0.00230825]
#  [ 0.01782013]
#  [ 0.00067502]
#  [ 0.05042115]
#  [ 0.04199574]
#  [ 0.00816951]
#  [ 0.02720497]
#  [ 0.00547197]
#  [ 0.089176  ]]
#
#
# Cost in iteraction 49: 2.77599677429
# Error convergence: 0.0352748803271
# Derivatives: [[ -1.20885953 -10.4404005   -0.57256048  -0.34141841  -2.48994314
#    -0.09802908  -3.82192688   4.79483725  -1.20441559  -4.01359632
#    -0.80998001 -13.25585916]]
# New betas:
# [[ 0.00831965]
#  [ 0.0716915 ]
#  [ 0.0040214 ]
#  [ 0.00234239]
#  [ 0.01806912]
#  [ 0.00068482]
#  [ 0.05080334]
#  [ 0.04151626]
#  [ 0.00828995]
#  [ 0.02760633]
#  [ 0.00555297]
#  [ 0.09050159]]
#
#
# Cost in iteraction 50: 2.74126713894
# Error convergence: 0.0347296353465
# Derivatives: [[ -1.20027454 -10.36392432  -0.56838368  -0.33897638  -2.47073951
#    -0.09731848  -3.75714924   4.74893374  -1.19585964  -3.98510765
#    -0.8043303  -13.16180478]]
# New betas:
# [[ 0.00843968]
#  [ 0.0727279 ]
#  [ 0.00407824]
#  [ 0.00237629]
#  [ 0.0183162 ]
#  [ 0.00069456]
#  [ 0.05117906]
#  [ 0.04104136]
#  [ 0.00840953]
#  [ 0.02800485]
#  [ 0.0056334 ]
#  [ 0.09181777]]
#
#
# Cost in iteraction 51: 2.70707375714
# Error convergence: 0.0341933818077
# Derivatives: [[ -1.19175742 -10.28804658  -0.56423957  -0.3365529   -2.45168938
#    -0.09661345  -3.69308043   4.703453    -1.18737133  -3.95684494
#    -0.79872533 -13.06849592]]
# New betas:
# [[ 0.00855886]
#  [ 0.0737567 ]
#  [ 0.00413467]
#  [ 0.00240994]
#  [ 0.01856136]
#  [ 0.00070422]
#  [ 0.05154837]
#  [ 0.04057102]
#  [ 0.00852827]
#  [ 0.02840053]
#  [ 0.00571327]
#  [ 0.09312462]]
#
#
# Cost in iteraction 52: 2.67340779119
# Error convergence: 0.0336659659489
# Derivatives: [[ -1.1833076  -10.21276231  -0.56012786  -0.33414779  -2.43279145
#    -0.09591396  -3.62971357   4.6583912   -1.17895009  -3.9288063
#    -0.79316473 -12.97592632]]
# New betas:
# [[ 0.00867719]
#  [ 0.07477798]
#  [ 0.00419068]
#  [ 0.00244336]
#  [ 0.01880464]
#  [ 0.00071381]
#  [ 0.05191134]
#  [ 0.04010518]
#  [ 0.00864617]
#  [ 0.02879341]
#  [ 0.00579259]
#  [ 0.09442221]]
#
#
# Cost in iteraction 53: 2.6402605545
# Error convergence: 0.0331472366885
# Derivatives: [[ -1.17492453 -10.13806659  -0.55604829  -0.33176092  -2.41404445
#    -0.09521995  -3.56704184   4.61374456  -1.17059536  -3.90098985
#    -0.78764811 -12.8840898 ]]
# New betas:
# [[ 0.00879468]
#  [ 0.07579178]
#  [ 0.00424628]
#  [ 0.00247654]
#  [ 0.01904605]
#  [ 0.00072333]
#  [ 0.05226804]
#  [ 0.03964381]
#  [ 0.00876322]
#  [ 0.02918351]
#  [ 0.00587135]
#  [ 0.09571062]]
#
#
# Cost in iteraction 54: 2.60762350892
# Error convergence: 0.0326370455776
# Derivatives: [[ -1.16660764 -10.06395452  -0.55200059  -0.32939214  -2.39544711
#    -0.09453137  -3.50505848   4.56950931  -1.16230658  -3.87339373
#    -0.78217513 -12.7929802 ]]
# New betas:
# [[ 0.00891134]
#  [ 0.07679818]
#  [ 0.00430148]
#  [ 0.00250947]
#  [ 0.01928559]
#  [ 0.00073278]
#  [ 0.05261855]
#  [ 0.03918685]
#  [ 0.00887946]
#  [ 0.02957085]
#  [ 0.00594957]
#  [ 0.09698992]]
#
#
# Cost in iteraction 55: 2.57548826217
# Error convergence: 0.0321352467537
# Derivatives: [[ -1.15835638  -9.99042124  -0.5479845   -0.32704129  -2.37699816
#    -0.09384819  -3.44375679   4.52568172  -1.15408321  -3.84601608
#    -0.7767454  -12.70259143]]
# New betas:
# [[ 0.00902718]
#  [ 0.07779722]
#  [ 0.00435628]
#  [ 0.00254218]
#  [ 0.01952329]
#  [ 0.00074217]
#  [ 0.05296292]
#  [ 0.03873429]
#  [ 0.00899486]
#  [ 0.02995545]
#  [ 0.00602725]
#  [ 0.09826018]]
#
#
# Cost in iteraction 56: 2.54384656527
# Error convergence: 0.0316416968956
# Derivatives: [[ -1.1501702   -9.91746197  -0.54399976  -0.32470824  -2.35869637
#    -0.09317036  -3.38313016   4.48225812  -1.14592469  -3.81885508
#    -0.77135857 -12.61291746]]
# New betas:
# [[ 0.00914219]
#  [ 0.07878897]
#  [ 0.00441068]
#  [ 0.00257465]
#  [ 0.01975916]
#  [ 0.00075149]
#  [ 0.05330124]
#  [ 0.03828606]
#  [ 0.00910946]
#  [ 0.03033734]
#  [ 0.00610438]
#  [ 0.09952147]]
#
#
# Cost in iteraction 57: 2.51269031009
# Error convergence: 0.031156255178
# Derivatives: [[ -1.14204855  -9.84507192  -0.5400461   -0.32239283  -2.34054049
#    -0.09249783  -3.32317199   4.43923483  -1.13783048  -3.79190891
#    -0.76601428 -12.52395229]]
# New betas:
# [[ 0.0092564 ]
#  [ 0.07977347]
#  [ 0.00446469]
#  [ 0.00260689]
#  [ 0.01999322]
#  [ 0.00076073]
#  [ 0.05363355]
#  [ 0.03784214]
#  [ 0.00922324]
#  [ 0.03071653]
#  [ 0.00618098]
#  [ 0.10077386]]
#
#
# Cost in iteraction 58: 2.48201152687
# Error convergence: 0.0306787832285
# Derivatives: [[ -1.13399091  -9.77324637  -0.53612327  -0.32009493  -2.32252929
#    -0.09183056  -3.26387579   4.39660823  -1.12980006  -3.76517578
#    -0.76071217 -12.43569   ]]
# New betas:
# [[ 0.0093698 ]
#  [ 0.0807508 ]
#  [ 0.0045183 ]
#  [ 0.0026389 ]
#  [ 0.02022547]
#  [ 0.00076992]
#  [ 0.05395994]
#  [ 0.03740248]
#  [ 0.00933622]
#  [ 0.03109304]
#  [ 0.00625705]
#  [ 0.10201743]]
#
#
# Cost in iteraction 59: 2.45180238178
# Error convergence: 0.0302091450834
# Derivatives: [[ -1.12599672  -9.70198064  -0.532231    -0.31781439  -2.30466157
#    -0.09116851  -3.2052351    4.35437473  -1.12183287  -3.73865389
#    -0.7554519  -12.34812471]]
# New betas:
# [[ 0.0094824 ]
#  [ 0.081721  ]
#  [ 0.00457152]
#  [ 0.00267068]
#  [ 0.02045594]
#  [ 0.00077903]
#  [ 0.05428046]
#  [ 0.03696704]
#  [ 0.0094484 ]
#  [ 0.03146691]
#  [ 0.0063326 ]
#  [ 0.10325225]]
#
#
# Cost in iteraction 60: 2.42205517464
# Error convergence: 0.0297472071462
# Derivatives: [[ -1.11806547  -9.63127009  -0.52836906  -0.31555106  -2.28693611
#    -0.09051163  -3.14724354   4.31253077  -1.1139284   -3.71234149
#    -0.7502331  -12.26125057]]
# New betas:
# [[ 0.0095942 ]
#  [ 0.08268412]
#  [ 0.00462436]
#  [ 0.00270223]
#  [ 0.02068463]
#  [ 0.00078809]
#  [ 0.05459519]
#  [ 0.03653579]
#  [ 0.0095598 ]
#  [ 0.03183814]
#  [ 0.00640762]
#  [ 0.10447837]]
#
#
# Cost in iteraction 61: 2.39276233649
# Error convergence: 0.0292928381457
# Derivatives: [[ -1.11019662  -9.56111012  -0.52453717  -0.31330482  -2.26935173
#    -0.08985987  -3.08989478   4.27107281  -1.10608612  -3.68623682
#    -0.74505544 -12.17506181]]
# New betas:
# [[ 0.00970522]
#  [ 0.08364023]
#  [ 0.00467681]
#  [ 0.00273357]
#  [ 0.02091156]
#  [ 0.00079707]
#  [ 0.05490418]
#  [ 0.03610868]
#  [ 0.0096704 ]
#  [ 0.03220677]
#  [ 0.00648213]
#  [ 0.10569588]]
#
#
# Cost in iteraction 62: 2.3639164274
# Error convergence: 0.028845909095
# Derivatives: [[ -1.10238966  -9.49149615  -0.52073511  -0.31107552  -2.25190723
#    -0.08921321  -3.03318253   4.22999737  -1.09830551  -3.66033813
#    -0.73991857 -12.0895527 ]]
# New betas:
# [[ 0.00981546]
#  [ 0.08458938]
#  [ 0.00472889]
#  [ 0.00276467]
#  [ 0.02113675]
#  [ 0.00080599]
#  [ 0.0552075 ]
#  [ 0.03568568]
#  [ 0.00978023]
#  [ 0.0325728 ]
#  [ 0.00655612]
#  [ 0.10690483]]
#
#
# Cost in iteraction 63: 2.33551013414
# Error convergence: 0.0284062932512
# Derivatives: [[ -1.09464407  -9.42242366  -0.5169626   -0.30886303  -2.23460144
#    -0.08857159  -2.9771006    4.18930097  -1.09058606  -3.63464372
#    -0.73482215 -12.00471755]]
# New betas:
# [[ 0.00992493]
#  [ 0.08553163]
#  [ 0.00478058]
#  [ 0.00279556]
#  [ 0.02136021]
#  [ 0.00081485]
#  [ 0.05550521]
#  [ 0.03526675]
#  [ 0.00988929]
#  [ 0.03293627]
#  [ 0.0066296 ]
#  [ 0.1081053 ]]
#
#
# Cost in iteraction 64: 2.30753626807
# Error convergence: 0.0279738660764
# Derivatives: [[ -1.08695934  -9.35388817  -0.51321943  -0.3066672   -2.21743321
#    -0.08793497  -2.92164283   4.14898017  -1.08292725  -3.60915186
#    -0.72976584 -11.92055073]]
# New betas:
# [[ 0.01003362]
#  [ 0.08646702]
#  [ 0.0048319 ]
#  [ 0.00282623]
#  [ 0.02158196]
#  [ 0.00082364]
#  [ 0.05579737]
#  [ 0.03485185]
#  [ 0.00999759]
#  [ 0.03329718]
#  [ 0.00670258]
#  [ 0.10929736]]
#
#
# Cost in iteraction 65: 2.27998776287
# Error convergence: 0.0275485051985
# Derivatives: [[ -1.07933496  -9.28588523  -0.50950533  -0.3044879   -2.20040137
#    -0.08730331  -2.86680311   4.10903158  -1.07532859  -3.58386087
#    -0.72474931 -11.83704665]]
# New betas:
# [[ 0.01014155]
#  [ 0.0873956 ]
#  [ 0.00488285]
#  [ 0.00285667]
#  [ 0.021802  ]
#  [ 0.00083237]
#  [ 0.05608405]
#  [ 0.03444095]
#  [ 0.01010512]
#  [ 0.03365557]
#  [ 0.00677505]
#  [ 0.11048106]]
#
#
# Cost in iteraction 66: 2.2528576725
# Error convergence: 0.0271300903736
# Derivatives: [[ -1.07177042  -9.21841043  -0.50582007  -0.302325    -2.18350479
#    -0.08667657  -2.8125754    4.06945182  -1.06778957  -3.55876907
#    -0.71977222 -11.75419979]]
# New betas:
# [[ 0.01024873]
#  [ 0.08831744]
#  [ 0.00493344]
#  [ 0.00288691]
#  [ 0.02202035]
#  [ 0.00084104]
#  [ 0.05636531]
#  [ 0.034034  ]
#  [ 0.0102119 ]
#  [ 0.03401144]
#  [ 0.00684703]
#  [ 0.11165648]]
#
#
# Cost in iteraction 67: 2.22613916905
# Error convergence: 0.0267185034478
# Derivatives: [[ -1.06426523  -9.1514594   -0.5021634   -0.30017837  -2.16674232
#    -0.08605471  -2.75895372   4.03023755  -1.06030969  -3.5338748
#    -0.71483425 -11.67200464]]
# New betas:
# [[ 0.01035516]
#  [ 0.08923259]
#  [ 0.00498365]
#  [ 0.00291692]
#  [ 0.02223702]
#  [ 0.00084965]
#  [ 0.0566412 ]
#  [ 0.03363098]
#  [ 0.01031793]
#  [ 0.03436483]
#  [ 0.00691851]
#  [ 0.11282368]]
#
#
# Cost in iteraction 68: 2.19982554073
# Error convergence: 0.0263136283216
# Derivatives: [[ -1.05681889  -9.0850278   -0.49853511  -0.29804787  -2.15011284
#    -0.08543769  -2.70593215   3.99138545  -1.05288845  -3.5091764
#    -0.70993507 -11.59045577]]
# New betas:
# [[ 0.01046084]
#  [ 0.09014109]
#  [ 0.00503351]
#  [ 0.00294673]
#  [ 0.02245203]
#  [ 0.00085819]
#  [ 0.0569118 ]
#  [ 0.03323184]
#  [ 0.01042322]
#  [ 0.03471575]
#  [ 0.00698951]
#  [ 0.11398273]]
#
#
# Cost in iteraction 69: 2.17391018981
# Error convergence: 0.0259153509125
# Derivatives: [[ -1.04943092  -9.01911135  -0.49493493  -0.29593337  -2.13361525
#    -0.08482547  -2.6535048    3.95289224  -1.04552538  -3.48467223
#    -0.70507435 -11.50954779]]
# New betas:
# [[ 0.01056578]
#  [ 0.091043  ]
#  [ 0.005083  ]
#  [ 0.00297632]
#  [ 0.0226654 ]
#  [ 0.00086667]
#  [ 0.05717715]
#  [ 0.03283655]
#  [ 0.01052777]
#  [ 0.03506422]
#  [ 0.00706002]
#  [ 0.11513368]]
#
#
# Cost in iteraction 70: 2.14838663069
# Error convergence: 0.0255235591208
# Derivatives: [[ -1.04210082  -8.95370577  -0.49136266  -0.29383474  -2.11724843
#    -0.08421801  -2.60166585   3.91475467  -1.03821999  -3.46036069
#    -0.70025178 -11.42927535]]
# New betas:
# [[ 0.01066999]
#  [ 0.09193838]
#  [ 0.00513214]
#  [ 0.00300571]
#  [ 0.02287712]
#  [ 0.0008751 ]
#  [ 0.05743731]
#  [ 0.03244508]
#  [ 0.01063159]
#  [ 0.03541025]
#  [ 0.00713004]
#  [ 0.11627661]]
#
#
# Cost in iteraction 71: 2.1232484879
# Error convergence: 0.0251381427939
# Derivatives: [[ -1.03482811  -8.88880684  -0.48781804  -0.29175186  -2.10101129
#    -0.08361526  -2.55040955   3.87696951  -1.03097179  -3.43624015
#    -0.69546704 -11.34963313]]
# New betas:
# [[ 0.01077348]
#  [ 0.09282726]
#  [ 0.00518092]
#  [ 0.00303488]
#  [ 0.02308722]
#  [ 0.00088346]
#  [ 0.05769235]
#  [ 0.03205738]
#  [ 0.01073469]
#  [ 0.03575388]
#  [ 0.00719959]
#  [ 0.11741158]]
#
#
# Cost in iteraction 72: 2.09848949421
# Error convergence: 0.0247589936924
# Derivatives: [[ -1.02761233  -8.82441038  -0.48430087  -0.2896846   -2.08490275
#    -0.0830172   -2.49973017   3.83953356  -1.02378031  -3.41230903
#    -0.69071981 -11.2706159 ]]
# New betas:
# [[ 0.01087624]
#  [ 0.0937097 ]
#  [ 0.00522935]
#  [ 0.00306385]
#  [ 0.02329571]
#  [ 0.00089176]
#  [ 0.05794233]
#  [ 0.03167343]
#  [ 0.01083707]
#  [ 0.03609511]
#  [ 0.00726866]
#  [ 0.11853864]]
#
#
# Cost in iteraction 73: 2.07410348875
# Error convergence: 0.0243860054565
# Derivatives: [[ -1.02045298  -8.76051224  -0.4808109   -0.28763282  -2.06892172
#    -0.08242378  -2.44962206   3.80244366  -1.01664508  -3.38856575
#    -0.68600978 -11.19221844]]
# New betas:
# [[ 0.01097828]
#  [ 0.09458575]
#  [ 0.00527743]
#  [ 0.00309261]
#  [ 0.0235026 ]
#  [ 0.0009    ]
#  [ 0.05818729]
#  [ 0.03129318]
#  [ 0.01093873]
#  [ 0.03643396]
#  [ 0.00733726]
#  [ 0.11965786]]
#
#
# Cost in iteraction 74: 2.05008441518
# Error convergence: 0.024019073573
# Derivatives: [[ -1.01334961  -8.6971083   -0.47734791  -0.28559642  -2.05306714
#    -0.08183496  -2.40007961   3.76569668  -1.00956563  -3.36500874
#    -0.68133664 -11.11443557]]
# New betas:
# [[ 0.01107962]
#  [ 0.09545546]
#  [ 0.00532516]
#  [ 0.00312117]
#  [ 0.02370791]
#  [ 0.00090818]
#  [ 0.0584273 ]
#  [ 0.03091661]
#  [ 0.01103969]
#  [ 0.03677046]
#  [ 0.00740539]
#  [ 0.1207693 ]]
#
#
# Cost in iteraction 75: 2.02642631983
# Error convergence: 0.0236580953428
# Derivatives: [[ -1.00630175  -8.63419448  -0.47391168  -0.28357525  -2.03733796
#    -0.0812507   -2.35109727   3.72928949  -1.0025415   -3.34163644
#    -0.67670008 -11.03726219]]
# New betas:
# [[ 0.01118025]
#  [ 0.09631888]
#  [ 0.00537255]
#  [ 0.00314953]
#  [ 0.02391164]
#  [ 0.00091631]
#  [ 0.05866241]
#  [ 0.03054368]
#  [ 0.01113994]
#  [ 0.03710463]
#  [ 0.00747306]
#  [ 0.12187303]]
#
#
# Cost in iteraction 76: 2.00312334999
# Error convergence: 0.023302969849
# Derivatives: [[ -0.99930893  -8.57176674  -0.47050199  -0.2815692   -2.02173312
#    -0.08067097  -2.30266954   3.69321902  -0.99557222  -3.31844733
#    -0.6720998  -10.96069321]]
# New betas:
# [[ 0.01128018]
#  [ 0.09717606]
#  [ 0.0054196 ]
#  [ 0.00317769]
#  [ 0.02411382]
#  [ 0.00092438]
#  [ 0.05889267]
#  [ 0.03017436]
#  [ 0.0112395 ]
#  [ 0.03743647]
#  [ 0.00754027]
#  [ 0.1229691 ]]
#
#
# Cost in iteraction 77: 1.98016975206
# Error convergence: 0.0229535979257
# Derivatives: [[ -0.9923707   -8.50982106  -0.46711862  -0.27957814  -2.00625159
#    -0.08009574  -2.25479096   3.65748222  -0.98865734  -3.29543986
#    -0.6675355  -10.8847236 ]]
# New betas:
# [[ 0.01137942]
#  [ 0.09802704]
#  [ 0.00546632]
#  [ 0.00320565]
#  [ 0.02431444]
#  [ 0.00093239]
#  [ 0.05911815]
#  [ 0.02980861]
#  [ 0.01133837]
#  [ 0.03776602]
#  [ 0.00760703]
#  [ 0.12405757]]
#
#
# Cost in iteraction 78: 1.95755986993
# Error convergence: 0.0226098821274
# Derivatives: [[ -0.9854866   -8.44835347  -0.46376136  -0.27760196  -1.99089232
#    -0.07952495  -2.20745613   3.62207605  -0.98179641  -3.27261254
#    -0.66300688 -10.80934838]]
# New betas:
# [[ 0.01147796]
#  [ 0.09887187]
#  [ 0.00551269]
#  [ 0.00323341]
#  [ 0.02451353]
#  [ 0.00094034]
#  [ 0.0593389 ]
#  [ 0.0294464 ]
#  [ 0.01143655]
#  [ 0.03809328]
#  [ 0.00767333]
#  [ 0.12513851]]
#
#
# Cost in iteraction 79: 1.93528814323
# Error convergence: 0.0222717266985
# Derivatives: [[ -0.97865619  -8.38736002  -0.46042998  -0.27564054  -1.97565432
#    -0.07895858  -2.1606597    3.58699752  -0.97498898  -3.24996385
#    -0.65851363 -10.73456258]]
# New betas:
# [[ 0.01157583]
#  [ 0.09971061]
#  [ 0.00555874]
#  [ 0.00326097]
#  [ 0.0247111 ]
#  [ 0.00094823]
#  [ 0.05955497]
#  [ 0.0290877 ]
#  [ 0.01153404]
#  [ 0.03841827]
#  [ 0.00773918]
#  [ 0.12621196]]
#
#
# Cost in iteraction 80: 1.91334910569
# Error convergence: 0.0219390375436
# Derivatives: [[ -0.97187902  -8.32683682  -0.45712427  -0.27369375  -1.96053654
#    -0.07839659  -2.11439638   3.55224364  -0.96823461  -3.22749232
#    -0.65405548 -10.66036131]]
# New betas:
# [[ 0.01167302]
#  [ 0.10054329]
#  [ 0.00560445]
#  [ 0.00328834]
#  [ 0.02490715]
#  [ 0.00095607]
#  [ 0.05976641]
#  [ 0.02873248]
#  [ 0.01163087]
#  [ 0.03874102]
#  [ 0.00780459]
#  [ 0.127278  ]]
#
#
# Cost in iteraction 81: 1.89173738349
# Error convergence: 0.0216117221989
# Derivatives: [[ -0.96515465  -8.26677998  -0.45384403  -0.27176148  -1.94553801
#    -0.07783895  -2.06866091   3.51781149  -0.96153285  -3.20519647
#    -0.64963211 -10.58673971]]
# New betas:
# [[ 0.01176953]
#  [ 0.10136997]
#  [ 0.00564983]
#  [ 0.00331551]
#  [ 0.02510171]
#  [ 0.00096386]
#  [ 0.05997327]
#  [ 0.0283807 ]
#  [ 0.01172702]
#  [ 0.03906154]
#  [ 0.00786955]
#  [ 0.12833667]]
#
#
# Cost in iteraction 82: 1.87044769369
# Error convergence: 0.0212896898028
# Derivatives: [[ -0.95848264  -8.20718565  -0.45058904  -0.2698436   -1.93065771
#    -0.07728561  -2.02344809   3.48369813  -0.95488327  -3.18307483
#    -0.64524326 -10.51369295]]
# New betas:
# [[ 0.01186538]
#  [ 0.10219069]
#  [ 0.00569489]
#  [ 0.0033425 ]
#  [ 0.02529477]
#  [ 0.00097159]
#  [ 0.06017562]
#  [ 0.02803233]
#  [ 0.01182251]
#  [ 0.03937985]
#  [ 0.00793407]
#  [ 0.12938804]]
#
#
# Cost in iteraction 83: 1.84947484262
# Error convergence: 0.0209728510684
# Derivatives: [[ -0.95186255  -8.14805005  -0.44735909  -0.26794002  -1.91589467
#    -0.07673654  -1.97875277   3.44990068  -0.94828544  -3.16112596
#    -0.64088862 -10.44121626]]
# New betas:
# [[ 0.01196057]
#  [ 0.10300549]
#  [ 0.00573963]
#  [ 0.00336929]
#  [ 0.02548636]
#  [ 0.00097926]
#  [ 0.06037349]
#  [ 0.02768734]
#  [ 0.01191734]
#  [ 0.03969596]
#  [ 0.00799816]
#  [ 0.13043216]]
#
#
# Cost in iteraction 84: 1.82881372436
# Error convergence: 0.0206611182557
# Derivatives: [[ -0.94529395  -8.08936937  -0.44415398  -0.2660506   -1.9012479
#    -0.07619171  -1.93456984   3.41641626  -0.94173892  -3.13934842
#    -0.63656792 -10.3693049 ]]
# New betas:
# [[ 0.0120551 ]
#  [ 0.10381443]
#  [ 0.00578404]
#  [ 0.0033959 ]
#  [ 0.02567649]
#  [ 0.00098688]
#  [ 0.06056695]
#  [ 0.0273457 ]
#  [ 0.01201151]
#  [ 0.0400099 ]
#  [ 0.00806182]
#  [ 0.13146909]]
#
#
# Cost in iteraction 85: 1.80845931922
# Error convergence: 0.0203544051443
# Derivatives: [[ -0.93877642  -8.0311399   -0.4409735   -0.26417523  -1.88671643
#    -0.07565108  -1.89089425   3.38324204  -0.93524329  -3.11774079
#    -0.63228087 -10.29795418]]
# New betas:
# [[ 0.01214898]
#  [ 0.10461754]
#  [ 0.00582814]
#  [ 0.00342232]
#  [ 0.02586516]
#  [ 0.00099444]
#  [ 0.06075604]
#  [ 0.02700737]
#  [ 0.01210504]
#  [ 0.04032167]
#  [ 0.00812505]
#  [ 0.13249889]]
#
#
# Cost in iteraction 86: 1.78840669221
# Error convergence: 0.0200526270067
# Derivatives: [[ -0.93230954  -7.9733579   -0.43781745  -0.26231381  -1.87229931
#    -0.07511462  -1.84772098   3.35037519  -0.92879813  -3.09630166
#    -0.6280272  -10.22715942]]
# New betas:
# [[ 0.01224221]
#  [ 0.10541488]
#  [ 0.00587192]
#  [ 0.00344855]
#  [ 0.02605239]
#  [ 0.00100196]
#  [ 0.06094081]
#  [ 0.02667234]
#  [ 0.01219792]
#  [ 0.0406313 ]
#  [ 0.00818785]
#  [ 0.1335216 ]]
#
#
# Cost in iteraction 87: 1.76865099163
# Error convergence: 0.0197557005826
# Derivatives: [[ -0.92589288  -7.9160197   -0.43468562  -0.26046622  -1.85799557
#    -0.07458229  -1.80504506   3.31781293  -0.92240303  -3.07502962
#    -0.62380662 -10.15691603]]
# New betas:
# [[ 0.0123348 ]
#  [ 0.10620648]
#  [ 0.00591539]
#  [ 0.00347459]
#  [ 0.02623819]
#  [ 0.00100941]
#  [ 0.06112131]
#  [ 0.02634055]
#  [ 0.01229016]
#  [ 0.04093881]
#  [ 0.00825023]
#  [ 0.1345373 ]]
#
#
# Cost in iteraction 88: 1.74918744758
# Error convergence: 0.0194635440525
# Derivatives: [[ -0.91952602  -7.85912166  -0.43157783  -0.25863235  -1.84380428
#    -0.07405406  -1.76286159   3.2855525   -0.91605756  -3.05392329
#    -0.61961887 -10.08721942]]
# New betas:
# [[ 0.01242675]
#  [ 0.10699239]
#  [ 0.00595855]
#  [ 0.00350046]
#  [ 0.02642257]
#  [ 0.00101682]
#  [ 0.0612976 ]
#  [ 0.026012  ]
#  [ 0.01238176]
#  [ 0.0412442 ]
#  [ 0.00831219]
#  [ 0.13554602]]
#
#
# Cost in iteraction 89: 1.73001137057
# Error convergence: 0.0191760770131
# Derivatives: [[ -0.91320856  -7.80266015  -0.42849387  -0.25681208  -1.82972449
#    -0.07352989  -1.7211657    3.25359114  -0.90976131  -3.0329813
#    -0.61546367 -10.01806505]]
# New betas:
# [[ 0.01251807]
#  [ 0.10777266]
#  [ 0.0060014 ]
#  [ 0.00352614]
#  [ 0.02660554]
#  [ 0.00102417]
#  [ 0.06146972]
#  [ 0.02568664]
#  [ 0.01247274]
#  [ 0.0415475 ]
#  [ 0.00837374]
#  [ 0.13654782]]
#
#
# Cost in iteraction 90: 1.71111815011
# Error convergence: 0.0188932204518
# Derivatives: [[-0.90694009 -7.74663159 -0.42543354 -0.25500532 -1.81575528 -0.07300976
#   -1.67995254  3.22192615 -0.90351388 -3.01220227 -0.61134075 -9.94944843]]
# New betas:
# [[ 0.01260876]
#  [ 0.10854732]
#  [ 0.00604394]
#  [ 0.00355164]
#  [ 0.02678711]
#  [ 0.00103147]
#  [ 0.06163771]
#  [ 0.02536445]
#  [ 0.01256309]
#  [ 0.04184872]
#  [ 0.00843487]
#  [ 0.13754277]]
#
#
# Cost in iteraction 91: 1.69250325339
# Error convergence: 0.0186148967228
# Derivatives: [[-0.9007202  -7.69103242 -0.42239666 -0.25321194 -1.80189573 -0.07249362
#   -1.63921735  3.19055483 -0.89731487 -2.99158486 -0.60724984 -9.88136509]]
# New betas:
# [[ 0.01269883]
#  [ 0.10931643]
#  [ 0.00608618]
#  [ 0.00357696]
#  [ 0.0269673 ]
#  [ 0.00103872]
#  [ 0.06180163]
#  [ 0.02504539]
#  [ 0.01265282]
#  [ 0.04214787]
#  [ 0.0084956 ]
#  [ 0.13853091]]
#
#
# Cost in iteraction 92: 1.67416222387
# Error convergence: 0.0183410295231
# Derivatives: [[-0.89454849 -7.63585912 -0.41938302 -0.25143185 -1.78814492 -0.07198145
#   -1.59895539  3.15947452 -0.89116387 -2.97112773 -0.60319068 -9.81381062]]
# New betas:
# [[ 0.01278829]
#  [ 0.11008001]
#  [ 0.00612812]
#  [ 0.0036021 ]
#  [ 0.02714612]
#  [ 0.00104592]
#  [ 0.06196153]
#  [ 0.02472944]
#  [ 0.01274194]
#  [ 0.04244499]
#  [ 0.00855592]
#  [ 0.13951229]]
#
#
# Cost in iteraction 93: 1.65609068
# Error convergence: 0.0180715438688
# Derivatives: [[-0.88842456 -7.5811082  -0.41639244 -0.24966494 -1.77450195 -0.07147321
#   -1.55916197  3.12868257 -0.88506048 -2.95082955 -0.59916301 -9.74678063]]
# New betas:
# [[ 0.01287713]
#  [ 0.11083812]
#  [ 0.00616976]
#  [ 0.00362707]
#  [ 0.02732357]
#  [ 0.00105307]
#  [ 0.06211745]
#  [ 0.02441658]
#  [ 0.01283044]
#  [ 0.04274007]
#  [ 0.00861583]
#  [ 0.14048696]]
#
#
# Cost in iteraction 94: 1.63828431393
# Error convergence: 0.0178063660718
# Derivatives: [[-0.88234801 -7.52677618 -0.41342473 -0.24791109 -1.76096592 -0.07096887
#   -1.51983243  3.09817636 -0.87900432 -2.93068899 -0.59516656 -9.68027078]]
# New betas:
# [[ 0.01296537]
#  [ 0.1115908 ]
#  [ 0.0062111 ]
#  [ 0.00365186]
#  [ 0.02749967]
#  [ 0.00106017]
#  [ 0.06226943]
#  [ 0.02410676]
#  [ 0.01291834]
#  [ 0.04303314]
#  [ 0.00867535]
#  [ 0.14145499]]
#
#
# Cost in iteraction 95: 1.62073889021
# Error convergence: 0.0175454237176
# Derivatives: [[-0.87631845 -7.47285963 -0.4104797  -0.24617021 -1.74753595 -0.0704684
#   -1.48096218  3.06795329 -0.87299498 -2.91070476 -0.59120108 -9.61427676]]
# New betas:
# [[ 0.013053  ]
#  [ 0.11233809]
#  [ 0.00625215]
#  [ 0.00367648]
#  [ 0.02767442]
#  [ 0.00106721]
#  [ 0.06241753]
#  [ 0.02379996]
#  [ 0.01300564]
#  [ 0.04332421]
#  [ 0.00873447]
#  [ 0.14241642]]
#
#
# Cost in iteraction 96: 1.60345024457
# Error convergence: 0.0172886456426
# Derivatives: [[-0.8703355  -7.41935514 -0.40755716 -0.2444422  -1.73421114 -0.06997177
#   -1.44254665  3.0380108  -0.8670321  -2.89087556 -0.58726631 -9.54879429]]
# New betas:
# [[ 0.01314003]
#  [ 0.11308002]
#  [ 0.0062929 ]
#  [ 0.00370092]
#  [ 0.02784784]
#  [ 0.00107421]
#  [ 0.06256178]
#  [ 0.02349616]
#  [ 0.01309235]
#  [ 0.0436133 ]
#  [ 0.0087932 ]
#  [ 0.1433713 ]]
#
#
# Cost in iteraction 97: 1.58641428265
# Error convergence: 0.0170359619124
# Derivatives: [[-0.86439877 -7.36625935 -0.40465693 -0.24272694 -1.72099063 -0.06947894
#   -1.40458133  3.00834634 -0.86111527 -2.8712001  -0.58336199 -9.48381914]]
# New betas:
# [[ 0.01322647]
#  [ 0.11381665]
#  [ 0.00633337]
#  [ 0.00372519]
#  [ 0.02801994]
#  [ 0.00108116]
#  [ 0.06270224]
#  [ 0.02319533]
#  [ 0.01317846]
#  [ 0.04390042]
#  [ 0.00885153]
#  [ 0.14431968]]
#
#
# Cost in iteraction 98: 1.56962697885
# Error convergence: 0.0167873038001
# Derivatives: [[-0.85850788 -7.31356889 -0.40177883 -0.24102434 -1.70787354 -0.06898988
#   -1.36706173  2.97895737 -0.85524412 -2.85167712 -0.57948789 -9.41934711]]
# New betas:
# [[ 0.01331232]
#  [ 0.11454801]
#  [ 0.00637355]
#  [ 0.0037493 ]
#  [ 0.02819073]
#  [ 0.00108806]
#  [ 0.06283894]
#  [ 0.02289743]
#  [ 0.01326398]
#  [ 0.04418559]
#  [ 0.00890948]
#  [ 0.14526162]]
#
#
# Cost in iteraction 99: 1.55308437509
# Error convergence: 0.0165426037651
# Derivatives: [[-0.85266245 -7.26128046 -0.39892267 -0.23933429 -1.69485903 -0.06850457
#   -1.32998342  2.94984139 -0.84941828 -2.83230535 -0.57564373 -9.35537405]]
# New betas:
# [[ 0.01339759]
#  [ 0.11527413]
#  [ 0.00641344]
#  [ 0.00377323]
#  [ 0.02836021]
#  [ 0.00109491]
#  [ 0.06297194]
#  [ 0.02260245]
#  [ 0.01334892]
#  [ 0.04446882]
#  [ 0.00896705]
#  [ 0.14619715]]
#
#
# Cost in iteraction 100: 1.53678257966
# Error convergence: 0.0163017954326
# Derivatives: [[-0.8468621  -7.20939075 -0.39608828 -0.2376567  -1.68194623 -0.06802297
#   -1.29334202  2.92099593 -0.84363737 -2.81308353 -0.57182929 -9.29189581]]
# New betas:
# [[ 0.01348228]
#  [ 0.11599507]
#  [ 0.00645305]
#  [ 0.003797  ]
#  [ 0.02852841]
#  [ 0.00110171]
#  [ 0.06310128]
#  [ 0.02231035]
#  [ 0.01343329]
#  [ 0.04475012]
#  [ 0.00902423]
#  [ 0.14712634]]
#
#
# Cost in iteraction 101: 1.52071776608
# Error convergence: 0.0160648135731
# Derivatives: [[-0.84110647 -7.15789651 -0.39327547 -0.23599147 -1.66913431 -0.06754505
#   -1.25713316  2.89241851 -0.83790101 -2.79401044 -0.5680443  -9.22890833]]
# New betas:
# [[ 0.01356639]
#  [ 0.11671086]
#  [ 0.00649238]
#  [ 0.0038206 ]
#  [ 0.02869532]
#  [ 0.00110846]
#  [ 0.06322699]
#  [ 0.02202111]
#  [ 0.01351708]
#  [ 0.04502953]
#  [ 0.00908103]
#  [ 0.14804923]]
#
#
# Cost in iteraction 102: 1.504886172
# Error convergence: 0.0158315940819
# Derivatives: [[-0.83539518 -7.1067945  -0.39048407 -0.23433849 -1.65642242 -0.06707079
#   -1.22135253  2.86410672 -0.83220885 -2.77508483 -0.56428854 -9.16640752]]
# New betas:
# [[ 0.01364993]
#  [ 0.11742154]
#  [ 0.00653143]
#  [ 0.00384403]
#  [ 0.02886096]
#  [ 0.00111517]
#  [ 0.06334913]
#  [ 0.0217347 ]
#  [ 0.0136003 ]
#  [ 0.04530703]
#  [ 0.00913746]
#  [ 0.14896587]]
#
#
# Cost in iteraction 103: 1.48928409804
# Error convergence: 0.0156020739602
# Derivatives: [[-0.82972786 -7.05608151 -0.38771391 -0.23269767 -1.64380973 -0.06660014
#   -1.18599588  2.83605812 -0.82656051 -2.7563055  -0.56056175 -9.10438939]]
# New betas:
# [[ 0.0137329 ]
#  [ 0.11812715]
#  [ 0.0065702 ]
#  [ 0.0038673 ]
#  [ 0.02902534]
#  [ 0.00112183]
#  [ 0.06346772]
#  [ 0.02145109]
#  [ 0.01368295]
#  [ 0.04558266]
#  [ 0.00919352]
#  [ 0.14987631]]
#
#
# Cost in iteraction 104: 1.47390790675
# Error convergence: 0.0153761912952
# Derivatives: [[-0.82410417 -7.00575436 -0.38496481 -0.23106891 -1.63129543 -0.06613308
#   -1.15105895  2.80827033 -0.82095564 -2.73767122 -0.5568637  -9.04284993]]
# New betas:
# [[ 0.01381531]
#  [ 0.11882773]
#  [ 0.00660869]
#  [ 0.00389041]
#  [ 0.02918847]
#  [ 0.00112844]
#  [ 0.06358283]
#  [ 0.02117026]
#  [ 0.01376505]
#  [ 0.04585643]
#  [ 0.0092492 ]
#  [ 0.1507806 ]]
#
#
# Cost in iteraction 105: 1.4587540215
# Error convergence: 0.0151538852411
# Derivatives: [[-0.81852372 -6.9558099  -0.3822366  -0.22945211 -1.61887869 -0.06566959
#   -1.11653757  2.78074098 -0.81539388 -2.71918081 -0.55319415 -8.9817852 ]]
# New betas:
# [[ 0.01389716]
#  [ 0.11952331]
#  [ 0.00664692]
#  [ 0.00391335]
#  [ 0.02935036]
#  [ 0.00113501]
#  [ 0.06369448]
#  [ 0.02089219]
#  [ 0.01384659]
#  [ 0.04612835]
#  [ 0.00930452]
#  [ 0.15167878]]
#
#
# Cost in iteraction 106: 1.4438189255
# Error convergence: 0.0149350960006
# Derivatives: [[-0.81298618 -6.90624499 -0.3795291  -0.22784719 -1.60655871 -0.06520963
#   -1.08242759  2.75346771 -0.80987487 -2.70083308 -0.54955287 -8.92119127]]
# New betas:
# [[ 0.01397846]
#  [ 0.12021393]
#  [ 0.00668487]
#  [ 0.00393614]
#  [ 0.02951102]
#  [ 0.00114153]
#  [ 0.06380273]
#  [ 0.02061684]
#  [ 0.01392758]
#  [ 0.04639843]
#  [ 0.00935948]
#  [ 0.1525709 ]]
#
#
# Cost in iteraction 107: 1.4290991607
# Error convergence: 0.0147197648066
# Derivatives: [[-0.80749119 -6.85705655 -0.37684216 -0.22625404 -1.59433468 -0.06475318
#   -1.04872488  2.72644819 -0.80439826 -2.68262684 -0.54593963 -8.86106427]]
# New betas:
# [[ 0.01405921]
#  [ 0.12089964]
#  [ 0.00672255]
#  [ 0.00395876]
#  [ 0.02967045]
#  [ 0.00114801]
#  [ 0.0639076 ]
#  [ 0.0203442 ]
#  [ 0.01400802]
#  [ 0.0466667 ]
#  [ 0.00941407]
#  [ 0.153457  ]]
#
#
# Cost in iteraction 108: 1.41459132679
# Error convergence: 0.014507833904
# Derivatives: [[-0.80203839 -6.8082415  -0.37417559 -0.22467257 -1.58220581 -0.0643002
#   -1.01542537  2.69968012 -0.7989637  -2.66456093 -0.54235419 -8.80140034]]
# New betas:
# ...
# Derivatives: [[-0.07470448 -0.23064008 -0.01332265 -0.00424274  0.00529592 -0.00340197
#    0.63996988 -0.02104357 -0.07400918 -0.26374719 -0.0654039  -0.8639687 ]]
# New betas:
# [[ 0.02658339]
#  [ 0.21450233]
#  [ 0.0119133 ]
#  [ 0.00700301]
#  [ 0.04903953]
#  [ 0.00207122]
#  [ 0.02867629]
#  [-0.00463223]
#  [ 0.02647117]
#  [ 0.08870727]
#  [ 0.01835604]
#  [ 0.29218069]]
#
#
# Cost in iteraction 561: 0.296460066354
# Error convergence: 0.000129231374127
# Derivatives: [[-0.07442426 -0.22808788 -0.01317756 -0.00415156  0.00586116 -0.00337829
#    0.63777434 -0.02122343 -0.07372987 -0.26282803 -0.06522208 -0.86091732]]
# New betas:
# [[ 0.02659083]
#  [ 0.21452514]
#  [ 0.01191462]
#  [ 0.00700342]
#  [ 0.04903895]
#  [ 0.00207156]
#  [ 0.02861251]
#  [-0.00463011]
#  [ 0.02647854]
#  [ 0.08873356]
#  [ 0.01836256]
#  [ 0.29226679]]
#
#
# Cost in iteraction 562: 0.296331814885
# Error convergence: 0.000128251469039
# Derivatives: [[-0.07414555 -0.2255497  -0.01303323 -0.00406086  0.00642314 -0.00335474
#    0.63558378 -0.0214002  -0.07345207 -0.26191382 -0.06504124 -0.85788228]]
# New betas:
# [[ 0.02659825]
#  [ 0.21454769]
#  [ 0.01191592]
#  [ 0.00700383]
#  [ 0.04903831]
#  [ 0.0020719 ]
#  [ 0.02854895]
#  [-0.00462797]
#  [ 0.02648589]
#  [ 0.08875975]
#  [ 0.01836907]
#  [ 0.29235257]]
#
#
# Cost in iteraction 563: 0.296204534559
# Error convergence: 0.000127280325796
# Derivatives: [[-0.07386834 -0.22302546 -0.01288965 -0.00397067  0.00698189 -0.00333132
#    0.6333982  -0.02157391 -0.07317576 -0.26100451 -0.06486139 -0.85486349]]
# New betas:
# [[ 0.02660563]
#  [ 0.21457   ]
#  [ 0.01191721]
#  [ 0.00700423]
#  [ 0.04903761]
#  [ 0.00207223]
#  [ 0.02848561]
#  [-0.00462581]
#  [ 0.02649321]
#  [ 0.08878585]
#  [ 0.01837555]
#  [ 0.29243806]]
#
#
# Cost in iteraction 564: 0.296078216697
# Error convergence: 0.000126317861495
# Derivatives: [[-0.07359262 -0.22051507 -0.01274683 -0.00388097  0.00753741 -0.00330803
#    0.63121763 -0.02174459 -0.07290094 -0.26010009 -0.06468251 -0.85186085]]
# New betas:
# [[ 0.02661299]
#  [ 0.21459205]
#  [ 0.01191849]
#  [ 0.00700461]
#  [ 0.04903685]
#  [ 0.00207256]
#  [ 0.02842249]
#  [-0.00462364]
#  [ 0.0265005 ]
#  [ 0.08881186]
#  [ 0.01838202]
#  [ 0.29252325]]
#
#
# Cost in iteraction 565: 0.295952852703
# Error convergence: 0.000125363994084
# Derivatives: [[-0.07331837 -0.21801845 -0.01260476 -0.00379175  0.00808974 -0.00328486
#    0.62904209 -0.02191228 -0.07262759 -0.25920051 -0.0645046  -0.84887425]]
# New betas:
# [[ 0.02662032]
#  [ 0.21461385]
#  [ 0.01191975]
#  [ 0.00700499]
#  [ 0.04903604]
#  [ 0.00207289]
#  [ 0.02835958]
#  [-0.00462145]
#  [ 0.02650776]
#  [ 0.08883778]
#  [ 0.01838847]
#  [ 0.29260813]]
#
#
# Cost in iteraction 566: 0.295828434061
# Error convergence: 0.000124418642349
# Derivatives: [[-0.0730456  -0.21553551 -0.01246342 -0.00370303  0.0086389  -0.00326182
#    0.62687158 -0.022077   -0.07235571 -0.25830576 -0.06432765 -0.8459036 ]]
# New betas:
# [[ 0.02662763]
#  [ 0.2146354 ]
#  [ 0.01192099]
#  [ 0.00700536]
#  [ 0.04903518]
#  [ 0.00207321]
#  [ 0.0282969 ]
#  [-0.00461924]
#  [ 0.02651499]
#  [ 0.08886361]
#  [ 0.0183949 ]
#  [ 0.29269272]]
#
#
# Cost in iteraction 567: 0.295704952335
# Error convergence: 0.000123481725912
# Derivatives: [[-0.0727743  -0.21306618 -0.01232283 -0.00361478  0.00918489 -0.0032389
#    0.62470614 -0.0222388  -0.07208529 -0.25741579 -0.06415166 -0.84294879]]
# New betas:
# [[ 0.02663491]
#  [ 0.21465671]
#  [ 0.01192222]
#  [ 0.00700572]
#  [ 0.04903426]
#  [ 0.00207354]
#  [ 0.02823443]
#  [-0.00461701]
#  [ 0.0265222 ]
#  [ 0.08888935]
#  [ 0.01840132]
#  [ 0.29277702]]
#
#
# Cost in iteraction 568: 0.29558239917
# Error convergence: 0.000122553165213
# Derivatives: [[-0.07250445 -0.21061036 -0.01218297 -0.00352702  0.00972775 -0.00321611
#    0.62254577 -0.0223977  -0.07181632 -0.25653059 -0.06397663 -0.84000973]]
# New betas:
# [[ 0.02664216]
#  [ 0.21467777]
#  [ 0.01192344]
#  [ 0.00700608]
#  [ 0.04903329]
#  [ 0.00207386]
#  [ 0.02817217]
#  [-0.00461477]
#  [ 0.02652938]
#  [ 0.088915  ]
#  [ 0.01840772]
#  [ 0.29286102]]
#
#
# Cost in iteraction 569: 0.295460766288
# Error convergence: 0.000121632881506
# Derivatives: [[-0.07223604 -0.20816799 -0.01204384 -0.00343974  0.01026749 -0.00319344
#    0.62039049 -0.02255374 -0.07154879 -0.25565011 -0.06380253 -0.83708633]]
# New betas:
# [[ 0.02664938]
#  [ 0.21469859]
#  [ 0.01192465]
#  [ 0.00700642]
#  [ 0.04903226]
#  [ 0.00207418]
#  [ 0.02811013]
#  [-0.00461252]
#  [ 0.02653654]
#  [ 0.08894057]
#  [ 0.0184141 ]
#  [ 0.29294473]]
#
#
# Cost in iteraction 570: 0.295340045491
# Error convergence: 0.000120720796848
# Derivatives: [[-0.07196907 -0.20573897 -0.01190544 -0.00335293  0.01080414 -0.00317089
#    0.61824032 -0.02270694 -0.07128269 -0.25477434 -0.06362938 -0.83417848]]
# New betas:
# [[ 0.02665658]
#  [ 0.21471916]
#  [ 0.01192584]
#  [ 0.00700676]
#  [ 0.04903118]
#  [ 0.0020745 ]
#  [ 0.02804831]
#  [-0.00461025]
#  [ 0.02654367]
#  [ 0.08896605]
#  [ 0.01842046]
#  [ 0.29302815]]
#
#
# Cost in iteraction 571: 0.295220228657
# Error convergence: 0.00011981683409
# Derivatives: [[-0.07170352 -0.20332323 -0.01176775 -0.00326659  0.01133771 -0.00314847
#    0.61609526 -0.02285734 -0.07101801 -0.25390323 -0.06345716 -0.83128609]]
# New betas:
# [[ 0.02666375]
#  [ 0.21473949]
#  [ 0.01192701]
#  [ 0.00700708]
#  [ 0.04903005]
#  [ 0.00207481]
#  [ 0.0279867 ]
#  [-0.00460796]
#  [ 0.02655077]
#  [ 0.08899144]
#  [ 0.01842681]
#  [ 0.29311128]]
#
#
# Cost in iteraction 572: 0.29510130774
# Error convergence: 0.000118920916868
# Derivatives: [[-0.07143939 -0.20092069 -0.01163078 -0.00318073  0.01186821 -0.00312617
#    0.61395535 -0.02300498 -0.07075475 -0.25303678 -0.06328587 -0.82840907]]
# New betas:
# [[ 0.02667089]
#  [ 0.21475959]
#  [ 0.01192818]
#  [ 0.0070074 ]
#  [ 0.04902886]
#  [ 0.00207512]
#  [ 0.0279253 ]
#  [-0.00460566]
#  [ 0.02655784]
#  [ 0.08901674]
#  [ 0.01843313]
#  [ 0.29319412]]
#
#
# Cost in iteraction 573: 0.294983274771
# Error convergence: 0.000118032969593
# Derivatives: [[-0.07117668 -0.19853127 -0.01149453 -0.00309533  0.01239568 -0.00310398
#    0.61182058 -0.02314987 -0.07049289 -0.25217493 -0.06311551 -0.82554732]]
# New betas:
# [[ 0.02667801]
#  [ 0.21477944]
#  [ 0.01192933]
#  [ 0.00700771]
#  [ 0.04902762]
#  [ 0.00207543]
#  [ 0.02786412]
#  [-0.00460335]
#  [ 0.02656489]
#  [ 0.08904196]
#  [ 0.01843945]
#  [ 0.29327667]]
#
#
# Cost in iteraction 574: 0.294866121853
# Error convergence: 0.000117152917445
# Derivatives: [[-0.07091536 -0.19615489 -0.01135898 -0.00301039  0.01292013 -0.00308192
#    0.60969097 -0.02329206 -0.07023243 -0.25131767 -0.06294606 -0.82270074]]
# New betas:
# [[ 0.0266851 ]
#  [ 0.21479905]
#  [ 0.01193046]
#  [ 0.00700801]
#  [ 0.04902633]
#  [ 0.00207574]
#  [ 0.02780315]
#  [-0.00460102]
#  [ 0.02657192]
#  [ 0.08906709]
#  [ 0.01844574]
#  [ 0.29335894]]
#
#
# Cost in iteraction 575: 0.294749841167
# Error convergence: 0.000116280686361
# Derivatives: [[-0.07065544 -0.19379147 -0.01122413 -0.00292592  0.01344157 -0.00305997
#    0.60756654 -0.02343157 -0.06997336 -0.25046497 -0.06277752 -0.81986924]]
# New betas:
# [[ 0.02669217]
#  [ 0.21481843]
#  [ 0.01193159]
#  [ 0.0070083 ]
#  [ 0.04902499]
#  [ 0.00207605]
#  [ 0.0277424 ]
#  [-0.00459867]
#  [ 0.02657891]
#  [ 0.08909214]
#  [ 0.01845202]
#  [ 0.29344093]]
#
#
# Cost in iteraction 576: 0.294634424964
# Error convergence: 0.000115416203028
# Derivatives: [[-0.0703969  -0.19144093 -0.01108999 -0.00284191  0.01396003 -0.00303815
#    0.6054473  -0.02356843 -0.06971567 -0.24961681 -0.06260988 -0.81705274]]
# New betas:
# [[ 0.02669921]
#  [ 0.21483758]
#  [ 0.01193269]
#  [ 0.00700859]
#  [ 0.04902359]
#  [ 0.00207635]
#  [ 0.02768185]
#  [-0.00459632]
#  [ 0.02658589]
#  [ 0.0891171 ]
#  [ 0.01845828]
#  [ 0.29352263]]
#
#
# Cost in iteraction 577: 0.294519865569
# Error convergence: 0.000114559394875
# Derivatives: [[-0.07013973 -0.1891032  -0.01095654 -0.00275836  0.01447553 -0.00301644
#    0.60333326 -0.02370267 -0.06945935 -0.24877314 -0.06244315 -0.81425113]]
# New betas:
# [[ 0.02670622]
#  [ 0.21485649]
#  [ 0.01193379]
#  [ 0.00700886]
#  [ 0.04902214]
#  [ 0.00207665]
#  [ 0.02762152]
#  [-0.00459395]
#  [ 0.02659283]
#  [ 0.08914197]
#  [ 0.01846452]
#  [ 0.29360406]]
#
#
# Cost in iteraction 578: 0.294406155379
# Error convergence: 0.000113710190064
# Derivatives: [[-0.06988394 -0.1867782  -0.01082378 -0.00267526  0.01498808 -0.00299485
#    0.60122443 -0.02383432 -0.06920439 -0.24793395 -0.06227731 -0.81146434]]
# New betas:
# [[ 0.02671321]
#  [ 0.21487517]
#  [ 0.01193487]
#  [ 0.00700913]
#  [ 0.04902064]
#  [ 0.00207695]
#  [ 0.0275614 ]
#  [-0.00459156]
#  [ 0.02659975]
#  [ 0.08916677]
#  [ 0.01847075]
#  [ 0.29368521]]
#
#
# Cost in iteraction 579: 0.294293286862
# Error convergence: 0.000112868517481
# Derivatives: [[-0.0696295  -0.18446585 -0.01069171 -0.00259261  0.0154977  -0.00297337
#    0.59912083 -0.02396341 -0.06895079 -0.2470992  -0.06211236 -0.80869225]]
# New betas:
# [[ 0.02672017]
#  [ 0.21489361]
#  [ 0.01193594]
#  [ 0.00700939]
#  [ 0.04901909]
#  [ 0.00207725]
#  [ 0.02750148]
#  [-0.00458917]
#  [ 0.02660665]
#  [ 0.08919148]
#  [ 0.01847696]
#  [ 0.29376607]]
#
#
# Cost in iteraction 580: 0.294181252555
# Error convergence: 0.000112034306728
# Derivatives: [[-0.06937641 -0.18216608 -0.01056032 -0.00251041  0.01600441 -0.00295201
#    0.59702247 -0.02408997 -0.06869853 -0.24626888 -0.0619483  -0.8059348 ]]
# New betas:
# [[ 0.02672711]
#  [ 0.21491183]
#  [ 0.011937  ]
#  [ 0.00700964]
#  [ 0.04901749]
#  [ 0.00207755]
#  [ 0.02744178]
#  [-0.00458676]
#  [ 0.02661352]
#  [ 0.0892161 ]
#  [ 0.01848316]
#  [ 0.29384667]]
#
#
# Cost in iteraction 581: 0.294070045067
# Error convergence: 0.000111207488119
# Derivatives: [[-0.06912467 -0.17987881 -0.01042961 -0.00242865  0.01650822 -0.00293076
#    0.59492935 -0.02421403 -0.06844761 -0.24544295 -0.06178511 -0.80319188]]
# New betas:
# [[ 0.02673402]
#  [ 0.21492982]
#  [ 0.01193804]
#  [ 0.00700988]
#  [ 0.04901584]
#  [ 0.00207784]
#  [ 0.02738229]
#  [-0.00458434]
#  [ 0.02662036]
#  [ 0.08924065]
#  [ 0.01848934]
#  [ 0.29392699]]
#
#
# Cost in iteraction 582: 0.293959657074
# Error convergence: 0.000110387992664
# Derivatives: [[-0.06887426 -0.17760398 -0.01029957 -0.00234734  0.01700917 -0.00290963
#    0.5928415  -0.02433561 -0.06819802 -0.24462138 -0.0616228  -0.80046341]]
# New betas:
# [[ 0.02674091]
#  [ 0.21494758]
#  [ 0.01193907]
#  [ 0.00701012]
#  [ 0.04901414]
#  [ 0.00207813]
#  [ 0.027323  ]
#  [-0.0045819 ]
#  [ 0.02662718]
#  [ 0.08926511]
#  [ 0.0184955 ]
#  [ 0.29400703]]
#
#
# Cost in iteraction 583: 0.293850081322
# Error convergence: 0.000109575752068
# Derivatives: [[-0.06862517 -0.1753415  -0.0101702  -0.00226647  0.01750726 -0.00288861
#    0.59075891 -0.02445475 -0.06794976 -0.24380416 -0.06146135 -0.79774931]]
# New betas:
# [[ 0.02674777]
#  [ 0.21496511]
#  [ 0.01194009]
#  [ 0.00701035]
#  [ 0.04901239]
#  [ 0.00207842]
#  [ 0.02726393]
#  [-0.00457946]
#  [ 0.02663398]
#  [ 0.08928949]
#  [ 0.01850164]
#  [ 0.29408681]]
#
#
# Cost in iteraction 584: 0.293741310623
# Error convergence: 0.000108770698723
# Derivatives: [[-0.0683774  -0.17309129 -0.0100415  -0.00218604  0.01800251 -0.00286771
#    0.58868161 -0.02457146 -0.0677028  -0.24299125 -0.06130077 -0.79504947]]
# New betas:
# [[ 0.02675461]
#  [ 0.21498242]
#  [ 0.01194109]
#  [ 0.00701056]
#  [ 0.04901059]
#  [ 0.00207871]
#  [ 0.02720506]
#  [-0.004577  ]
#  [ 0.02664075]
#  [ 0.08931379]
#  [ 0.01850777]
#  [ 0.29416631]]
#
#
# Cost in iteraction 585: 0.293633337858
# Error convergence: 0.000107972765694
# Derivatives: [[-0.06813095 -0.1708533  -0.00991347 -0.00210605  0.01849493 -0.00284691
#    0.58660959 -0.02468579 -0.06745716 -0.24218262 -0.06114104 -0.79236382]]
# New betas:
# [[ 0.02676142]
#  [ 0.21499951]
#  [ 0.01194208]
#  [ 0.00701078]
#  [ 0.04900874]
#  [ 0.00207899]
#  [ 0.0271464 ]
#  [-0.00457453]
#  [ 0.02664749]
#  [ 0.08933801]
#  [ 0.01851389]
#  [ 0.29424555]]
#
#
# Cost in iteraction 586: 0.293526155971
# Error convergence: 0.000107181886719
# Derivatives: [[-0.06788579 -0.16862744 -0.00978609 -0.00202649  0.01898456 -0.00282623
#    0.58454287 -0.02479775 -0.06721281 -0.24137826 -0.06098217 -0.78969227]]
# New betas:
# [[ 0.02676821]
#  [ 0.21501637]
#  [ 0.01194306]
#  [ 0.00701098]
#  [ 0.04900684]
#  [ 0.00207927]
#  [ 0.02708794]
#  [-0.00457205]
#  [ 0.02665421]
#  [ 0.08936215]
#  [ 0.01851999]
#  [ 0.29432452]]
#
#
# Cost in iteraction 587: 0.293419757975
# Error convergence: 0.000106397996198
# Derivatives: [[-0.06764193 -0.16641365 -0.00965937 -0.00194736  0.0194714  -0.00280566
#    0.58248146 -0.02490737 -0.06696975 -0.24057813 -0.06082414 -0.78703474]]
# New betas:
# [[ 0.02677497]
#  [ 0.21503301]
#  [ 0.01194403]
#  [ 0.00701117]
#  [ 0.0490049 ]
#  [ 0.00207955]
#  [ 0.0270297 ]
#  [-0.00456956]
#  [ 0.02666091]
#  [ 0.0893862 ]
#  [ 0.01852607]
#  [ 0.29440322]]
#
#
# Cost in iteraction 588: 0.293314136945
# Error convergence: 0.000105621029184
# Derivatives: [[-0.06739936 -0.16421185 -0.0095333  -0.00186866  0.01995547 -0.0027852
#    0.58042537 -0.02501468 -0.06672798 -0.23978221 -0.06066695 -0.78439113]]
# New betas:
# [[ 0.02678171]
#  [ 0.21504943]
#  [ 0.01194498]
#  [ 0.00701136]
#  [ 0.0490029 ]
#  [ 0.00207983]
#  [ 0.02697165]
#  [-0.00456706]
#  [ 0.02666758]
#  [ 0.08941018]
#  [ 0.01853214]
#  [ 0.29448166]]
#
#
# Cost in iteraction 589: 0.293209286024
# Error convergence: 0.000104850921381
# Derivatives: [[-0.06715806 -0.16202197 -0.00940787 -0.00179039  0.02043678 -0.00276485
#    0.57837461 -0.0251197  -0.06648748 -0.23899047 -0.0605106  -0.78176137]]
# New betas:
# [[ 0.02678843]
#  [ 0.21506563]
#  [ 0.01194592]
#  [ 0.00701154]
#  [ 0.04900086]
#  [ 0.00208011]
#  [ 0.02691382]
#  [-0.00456455]
#  [ 0.02667423]
#  [ 0.08943408]
#  [ 0.01853819]
#  [ 0.29455984]]
#
#
# Cost in iteraction 590: 0.293105198415
# Error convergence: 0.00010408760913
# Derivatives: [[-0.06691804 -0.15984393 -0.00928309 -0.00171254  0.02091536 -0.0027446
#    0.57632917 -0.02522247 -0.06624825 -0.23820289 -0.06035509 -0.77914537]]
# New betas:
# [[ 0.02679512]
#  [ 0.21508162]
#  [ 0.01194685]
#  [ 0.00701171]
#  [ 0.04899876]
#  [ 0.00208038]
#  [ 0.02685618]
#  [-0.00456203]
#  [ 0.02668086]
#  [ 0.0894579 ]
#  [ 0.01854422]
#  [ 0.29463775]]
#
#
# Cost in iteraction 591: 0.293001867386
# Error convergence: 0.000103331029407
# Derivatives: [[-0.06667928 -0.15767768 -0.00915895 -0.00163512  0.02139123 -0.00272447
#    0.57428908 -0.025323   -0.06601027 -0.23741944 -0.06020039 -0.77654304]]
# New betas:
# [[ 0.02680179]
#  [ 0.21509739]
#  [ 0.01194777]
#  [ 0.00701187]
#  [ 0.04899663]
#  [ 0.00208066]
#  [ 0.02679875]
#  [-0.00455949]
#  [ 0.02668746]
#  [ 0.08948164]
#  [ 0.01855024]
#  [ 0.29471541]]
#
#
# Cost in iteraction 592: 0.292899286266
# Error convergence: 0.000102581119817
# Derivatives: [[-0.06644177 -0.15552314 -0.00903544 -0.00155811  0.02186439 -0.00270444
#    0.57225434 -0.02542132 -0.06577355 -0.23664011 -0.06004653 -0.77395431]]
# New betas:
# [[ 0.02680843]
#  [ 0.21511294]
#  [ 0.01194867]
#  [ 0.00701203]
#  [ 0.04899444]
#  [ 0.00208093]
#  [ 0.02674153]
#  [-0.00455695]
#  [ 0.02669404]
#  [ 0.08950531]
#  [ 0.01855625]
#  [ 0.2947928 ]]
#
#
# Cost in iteraction 593: 0.292797448447
# Error convergence: 0.000101837818579
# Derivatives: [[-0.06620552 -0.15338024 -0.00891256 -0.00148152  0.02233486 -0.00268452
#    0.57022496 -0.02551747 -0.06553807 -0.23586485 -0.05989347 -0.77137909]]
# New betas:
# [[ 0.02681506]
#  [ 0.21512828]
#  [ 0.01194956]
#  [ 0.00701218]
#  [ 0.04899221]
#  [ 0.00208119]
#  [ 0.02668451]
#  [-0.0045544 ]
#  [ 0.02670059]
#  [ 0.08952889]
#  [ 0.01856224]
#  [ 0.29486994]]
#
#
# Cost in iteraction 594: 0.292696347383
# Error convergence: 0.00010110106453
# Derivatives: [[-0.0659705  -0.15124891 -0.00879032 -0.00140534  0.02280267 -0.0026647
#    0.56820093 -0.02561145 -0.06530383 -0.23509365 -0.05974123 -0.76881731]]
# New betas:
# [[ 0.02682165]
#  [ 0.2151434 ]
#  [ 0.01195044]
#  [ 0.00701232]
#  [ 0.04898993]
#  [ 0.00208146]
#  [ 0.02662769]
#  [-0.00455184]
#  [ 0.02670712]
#  [ 0.0895524 ]
#  [ 0.01856821]
#  [ 0.29494682]]
#
#
# Cost in iteraction 595: 0.292595976585
# Error convergence: 0.00010037079711
# Derivatives: [[-0.06573672 -0.14912909 -0.00866869 -0.00132958  0.02326782 -0.00264499
#    0.56618228 -0.0257033  -0.06507082 -0.23432649 -0.0595898  -0.76626887]]
# New betas:
# [[ 0.02682823]
#  [ 0.21515831]
#  [ 0.01195131]
#  [ 0.00701245]
#  [ 0.0489876 ]
#  [ 0.00208173]
#  [ 0.02657107]
#  [-0.00454927]
#  [ 0.02671363]
#  [ 0.08957584]
#  [ 0.01857417]
#  [ 0.29502345]]
#
#
# Cost in iteraction 596: 0.292496329629
# Error convergence: 9.96469563598e-05
# Derivatives: [[-0.06550416 -0.1470207  -0.00854769 -0.00125423  0.02373034 -0.00262539
#    0.56416901 -0.02579305 -0.06483903 -0.23356334 -0.05943916 -0.7637337 ]]
# New betas:
# [[ 0.02683478]
#  [ 0.21517302]
#  [ 0.01195216]
#  [ 0.00701258]
#  [ 0.04898523]
#  [ 0.00208199]
#  [ 0.02651465]
#  [-0.00454669]
#  [ 0.02672011]
#  [ 0.08959919]
#  [ 0.01858011]
#  [ 0.29509982]]

# %% [markdown]
# ### Plot Error Curve

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(errorArray[errorArray != 0])
plt.xlabel('Iteractions')
plt.ylabel('Minimum Square Error')
plt.title('Error Convergence')
plt.show()

# %% [markdown]
# ### Plot data and line

# %%
# How to plot N-Dimensional Regression? Is it going to be linear on a 2-d plot?


plt.scatter(np.array(x_data[:,1]), np.array(y_data))

predictedData = x_data * betas
plt.plot(np.array(x_data[:,1]), predictedData, 'r')

plt.xlabel('BMI')
plt.ylabel('Life Exp.')

plt.title('Linear Relationship BMI and Life Exp.')

plt.show()

# %% [markdown]
# ### What if we normalize the data first? How many iteractions we do? And can we increase the learning rate?

# %%
dataset_norm = (dataset - dataset.mean())/dataset.std()
print(dataset_norm.describe())
# Out:
#        fixed acidity  volatile acidity   citric acid  residual sugar  \
# count   1.599000e+03      1.599000e+03  1.599000e+03    1.599000e+03
# mean   -1.570643e-14     -1.590973e-15  6.045057e-15   -1.344696e-15
# std     1.000000e+00      1.000000e+00  1.000000e+00    1.000000e+00
# min    -2.136377e+00     -2.277567e+00 -1.391037e+00   -1.162333e+00
# 25%    -7.004996e-01     -7.696903e-01 -9.290275e-01   -4.530767e-01
# 50%    -2.410190e-01     -4.367545e-02 -5.634264e-02   -2.402999e-01
# 75%     5.056370e-01      6.264921e-01  7.650078e-01    4.340257e-02
# max     4.353787e+00      5.876138e+00  3.742403e+00    9.192806e+00
#
#           chlorides  free sulfur dioxide  total sulfur dioxide       density  \
# count  1.599000e+03         1.599000e+03          1.599000e+03  1.599000e+03
# mean   5.098590e-15        -7.724347e-17          1.619856e-16  3.772732e-13
# std    1.000000e+00         1.000000e+00          1.000000e+00  1.000000e+00
# min   -1.603443e+00        -1.422055e+00         -1.230199e+00 -3.537625e+00
# 25%   -3.711129e-01        -8.484502e-01         -7.438076e-01 -6.075656e-01
# 50%   -1.798892e-01        -1.792441e-01         -2.574163e-01  1.759533e-03
# 75%    5.382858e-02         4.899619e-01          4.721707e-01  5.766445e-01
# max    1.112355e+01         5.365606e+00          7.372847e+00  3.678904e+00
#
#                  pH     sulphates       alcohol
# count  1.599000e+03  1.599000e+03  1.599000e+03
# mean  -5.937923e-15 -2.175036e-15  2.580411e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.699244e+00 -1.935902e+00 -1.898325e+00
# 25%   -6.549356e-01 -6.380200e-01 -8.661079e-01
# 50%   -7.210449e-03 -2.250577e-01 -2.092427e-01
# 75%    5.757422e-01  4.238832e-01  6.352984e-01
# max    4.526866e+00  7.916200e+00  4.201138e+00

# %% [markdown]
# ### Convert dataset_norm to matrix, execute and evaluate betas, iteractions and convergence

# %%
# convert data_norm to matrix
x_data_norm = np.matrix(
                np.column_stack([np.repeat(1, len(dataset)), dataset_norm])
              )

# much bigger learning rate 0.1 against 0.0001 = less iteractions (285 against 596 for the same
# error convergence threshold)
(betas_norm, errorArray_norm) = linearRegressionRun(x_data_norm, y_data, learningRate = 0.1)
# Out:
# Cost in iteraction 0: 16.2082551595
# Derivatives: [[-5.63602251 -0.10011767  0.31520528 -0.1826972  -0.01108232  0.10403589
#    0.0408827   0.14938785  0.14117108  0.04659295 -0.20289363 -0.38429689]]
# New betas:
# [[ 0.56360225]
#  [ 0.01001177]
#  [-0.03152053]
#  [ 0.01826972]
#  [ 0.00110823]
#  [-0.01040359]
#  [-0.00408827]
#  [-0.01493879]
#  [-0.01411711]
#  [-0.0046593 ]
#  [ 0.02028936]
#  [ 0.03842969]]
#
#
# Cost in iteraction 1: 13.1552314891
# Error convergence: 3.05302367041
# Derivatives: [[-5.07242026 -0.07321117  0.25485453 -0.13461822 -0.01352442  0.09313648
#    0.02302085  0.1208467   0.12259576  0.02990477 -0.16914502 -0.32448914]]
# New betas:
# [[ 1.07084428]
#  [ 0.01733288]
#  [-0.05700598]
#  [ 0.03173154]
#  [ 0.00246067]
#  [-0.01971724]
#  [-0.00639036]
#  [-0.02702345]
#  [-0.02637668]
#  [-0.00764977]
#  [ 0.03720387]
#  [ 0.0708786 ]]
#
#
# Cost in iteraction 2: 10.6870067795
# Error convergence: 2.46822470957
# Derivatives: [[-4.56517824 -0.05438074  0.20666713 -0.09817112 -0.01548927  0.08262345
#    0.00986063  0.09815146  0.10482406  0.01916786 -0.14232942 -0.27407566]]
# New betas:
# [[ 1.5273621 ]
#  [ 0.02277096]
#  [-0.07767269]
#  [ 0.04154865]
#  [ 0.0040096 ]
#  [-0.02797958]
#  [-0.00737642]
#  [-0.0368386 ]
#  [-0.03685909]
#  [-0.00956656]
#  [ 0.05143681]
#  [ 0.09828617]]
#
#
# Cost in iteraction 3: 8.69077315463
# Error convergence: 1.99623362486
# Derivatives: [[ -4.10866041e+00  -4.11763475e-02   1.68024082e-01  -7.03736547e-02
#    -1.69102600e-02   7.28544231e-02   2.81268753e-04   8.01201999e-02
#     8.84965806e-02   1.24250600e-02  -1.20796473e-01  -2.31652028e-01]]
# New betas:
# [[ 1.93822814]
#  [ 0.02688859]
#  [-0.0944751 ]
#  [ 0.04858602]
#  [ 0.00570063]
#  [-0.03526502]
#  [-0.00740455]
#  [-0.04485062]
#  [-0.04570875]
#  [-0.01080906]
#  [ 0.06351645]
#  [ 0.12145137]]
#
#
# Cost in iteraction 4: 7.07578629114
# Error convergence: 1.61498686349
# Derivatives: [[-3.69779437 -0.03189264  0.13691714 -0.04905792 -0.01780121  0.0639946
#   -0.00657913  0.06580217  0.07389807  0.00834054 -0.10333067 -0.19599269]]
# New betas:
# [[ 2.30800758]
#  [ 0.03007786]
#  [-0.10816682]
#  [ 0.05349181]
#  [ 0.00748075]
#  [-0.04166448]
#  [-0.00674663]
#  [-0.05143084]
#  [-0.05309856]
#  [-0.01164312]
#  [ 0.07384952]
#  [ 0.14105064]]
#
#
# Cost in iteraction 5: 5.76892789028
# Error convergence: 1.30685840086
# Derivatives: [[-3.32801493 -0.02534188  0.11179468 -0.03263727 -0.01821773  0.0560908
#   -0.01138314  0.05443465  0.0610955   0.00600536 -0.08902883 -0.16604006]]
# New betas:
# [[ 2.64080907]
#  [ 0.03261205]
#  [-0.11934628]
#  [ 0.05675554]
#  [ 0.00930252]
#  [-0.04727356]
#  [-0.00560832]
#  [-0.0568743 ]
#  [-0.0592081 ]
#  [-0.01224365]
#  [ 0.0827524 ]
#  [ 0.15765465]]
#
#
# Cost in iteraction 6: 4.71121207622
# Error convergence: 1.05771581406
# Derivatives: [[-2.99521344 -0.02069638  0.09144914 -0.01994203 -0.01823346  0.04911997
#   -0.01463972  0.04540728  0.05002839  0.00480348 -0.07721359 -0.14088919]]
# New betas:
# [[ 2.94033042]
#  [ 0.03468168]
#  [-0.1284912 ]
#  [ 0.05874974]
#  [ 0.01112587]
#  [-0.05218556]
#  [-0.00414435]
#  [-0.06141503]
#  [-0.06421094]
#  [-0.012724  ]
#  [ 0.09047376]
#  [ 0.17174356]]
#
#
# Cost in iteraction 7: 3.85501275861
# Error convergence: 0.856199317612
# Derivatives: [[-2.6956921  -0.01737909  0.07493423 -0.01010332 -0.017926    0.04302051
#   -0.01673927  0.03823271  0.04056717  0.00431959 -0.06737199 -0.11977066]]
# New betas:
# [[  3.20989963e+00]
#  [  3.64195925e-02]
#  [ -1.35984621e-01]
#  [  5.97600734e-02]
#  [  1.29184655e-02]
#  [ -5.64876125e-02]
#  [ -2.47041963e-03]
#  [ -6.52383021e-02]
#  [ -6.82676607e-02]
#  [ -1.31559609e-02]
#  [  9.72109621e-02]
#  [  1.83720630e-01]]
#
#
# Cost in iteraction 8: 3.16185114958
# Error convergence: 0.693161609033
# Derivatives: [[-2.42612289 -0.01498755  0.06150368 -0.00247062 -0.01736905  0.03771221
#   -0.01798069  0.03252266  0.03255001  0.00427556 -0.05911174 -0.10203353]]
# New betas:
# [[  3.45251192e+00]
#  [  3.79183475e-02]
#  [ -1.42134989e-01]
#  [  6.00071353e-02]
#  [  1.46553706e-02]
#  [ -6.02588339e-02]
#  [ -6.72350278e-04]
#  [ -6.84905676e-02]
#  [ -7.15226616e-02]
#  [ -1.35835174e-02]
#  [  1.03122136e-01]
#  [  1.93923983e-01]]
#
#
# Cost in iteraction 9: 2.60062362765
# Error convergence: 0.561227521926
# Derivatives: [[-2.1835106  -0.01324103  0.05056546  0.00344703 -0.01662844  0.03310856
#   -0.01859222  0.02796842  0.02580563  0.00448688 -0.05212984 -0.08712914]]
# New betas:
# [[  3.67086298e+00]
#  [  3.92424503e-02]
#  [ -1.47191535e-01]
#  [  5.96624319e-02]
#  [  1.63182150e-02]
#  [ -6.35696902e-02]
#  [  1.18687175e-03]
#  [ -7.12874093e-02]
#  [ -7.41032242e-02]
#  [ -1.40322056e-02]
#  [  1.08335120e-01]
#  [  2.02636897e-01]]
#
#
# Cost in iteraction 10: 2.14617855896
# Error convergence: 0.454445068686
# Derivatives: [[-1.96515954 -0.01194371  0.04164735  0.00802318 -0.01576053  0.02912407
#   -0.01874755  0.02432503  0.02016667  0.00483264 -0.04618996 -0.0745964 ]]
# New betas:
# [[  3.86737893e+00]
#  [  4.04368214e-02]
#  [ -1.51356270e-01]
#  [  5.88601141e-02]
#  [  1.78942679e-02]
#  [ -6.64820971e-02]
#  [  3.06162687e-03]
#  [ -7.37199125e-02]
#  [ -7.61198913e-02]
#  [ -1.45154698e-02]
#  [  1.12954117e-01]
#  [  2.10096537e-01]]
#
#
# Cost in iteraction 11: 1.77817119335
# Error convergence: 0.368007365618
# Derivatives: [[-1.76864358 -0.01095907  0.03437087  0.01154426 -0.01481202  0.02567838
#   -0.01857833  0.02139851  0.01547717  0.00523501 -0.04110602 -0.06404865]]
# New betas:
# [[ 4.04424329]
#  [ 0.04153273]
#  [-0.15479336]
#  [ 0.05770569]
#  [ 0.01937547]
#  [-0.06904993]
#  [ 0.00491946]
#  [-0.07585976]
#  [-0.07766761]
#  [-0.01503897]
#  [ 0.11706472]
#  [ 0.2165014 ]]
#
#
# Cost in iteraction 12: 1.48014101689
# Error convergence: 0.298030176454
# Derivatives: [[-1.59177923 -0.010192    0.02843139  0.01423166 -0.01382056  0.02269833
#   -0.01818381  0.01903553  0.01159614  0.00564513 -0.03673015 -0.0551622 ]]
# New betas:
# [[ 4.20342121]
#  [ 0.04255193]
#  [-0.1576365 ]
#  [ 0.05628252]
#  [ 0.02075753]
#  [-0.07131977]
#  [ 0.00673784]
#  [-0.07776332]
#  [-0.07882722]
#  [-0.01560348]
#  [ 0.12073773]
#  [ 0.22201762]]
#
#
# Cost in iteraction 13: 1.23876756491
# Error convergence: 0.24137345198
# Derivatives: [[-1.4326013  -0.00957631  0.02358274  0.01625769 -0.01281576  0.02011875
#   -0.01763833  0.01711512  0.00839876  0.00603355 -0.03294388 -0.04766637]]
# New betas:
# [[ 4.34668134]
#  [ 0.04350956]
#  [-0.15999477]
#  [ 0.05465675]
#  [ 0.0220391 ]
#  [-0.07333164]
#  [ 0.00850167]
#  [-0.07947483]
#  [-0.0796671 ]
#  [-0.01620684]
#  [ 0.12403212]
#  [ 0.22678426]]
#
#
# Cost in iteraction 14: 1.04326969372
# Error convergence: 0.19549787119
# Derivatives: [[-1.28934117 -0.00906605  0.01962535  0.01775743 -0.01182022  0.01788241
#   -0.01699716  0.01554205  0.00577629  0.00638359 -0.02965149 -0.04133499]]
# New betas:
# [[ 4.47561546]
#  [ 0.04441617]
#  [-0.1619573 ]
#  [ 0.05288101]
#  [ 0.02322112]
#  [-0.07511988]
#  [ 0.01020139]
#  [-0.08102903]
#  [-0.08024473]
#  [-0.0168452 ]
#  [ 0.12699727]
#  [ 0.23091776]]
#
#
# Cost in iteraction 15: 0.884920351393
# Error convergence: 0.15834934233
# Derivatives: [[-1.16040706 -0.00862939  0.01639694  0.01883745 -0.01085077  0.01593967
#   -0.01630093  0.01424149  0.003635    0.00668699 -0.02677513 -0.03597921]]
# New betas:
# [[ 4.59165616]
#  [ 0.0452791 ]
#  [-0.163597  ]
#  [ 0.05099727]
#  [ 0.0243062 ]
#  [-0.07671385]
#  [ 0.01183148]
#  [-0.08245318]
#  [-0.08060823]
#  [-0.0175139 ]
#  [ 0.12967478]
#  [ 0.23451568]]
#
#
# Cost in iteraction 16: 0.75665444576
# Error convergence: 0.128265905633
# Derivatives: [[-1.04436635 -0.00824437  0.01376526  0.01958228 -0.0099194   0.01424777
#   -0.01557917  0.01315476  0.00189483  0.0069408  -0.02425098 -0.03144134]]
# New betas:
# [[ 4.6960928 ]
#  [ 0.04610354]
#  [-0.16497352]
#  [ 0.04903904]
#  [ 0.02529814]
#  [-0.07813863]
#  [ 0.0133894 ]
#  [-0.08376866]
#  [-0.08079771]
#  [-0.01820798]
#  [ 0.13209988]
#  [ 0.23765981]]
#
#
# Cost in iteraction 17: 0.652751821227
# Error convergence: 0.103902624533
# Derivatives: [[ -9.39929715e-01  -7.89592706e-03   1.16222517e-02   2.00593578e-02
#    -9.03426203e-03   1.27701107e-02  -1.48529599e-02   1.22359233e-02
#     4.87892137e-04   7.14544070e-03  -2.20264945e-02  -2.75897407e-02]]
# New betas:
# [[ 4.79008577]
#  [ 0.04689313]
#  [-0.16613575]
#  [ 0.0470331 ]
#  [ 0.02620157]
#  [-0.07941564]
#  [ 0.0148747 ]
#  [-0.08499225]
#  [-0.0808465 ]
#  [-0.01892252]
#  [ 0.13430253]
#  [ 0.24041879]]
#
#
# Cost in iteraction 18: 0.56858087516
# Error convergence: 0.0841709460665
# Derivatives: [[ -8.45936744e-01  -7.57377966e-03   9.87951692e-03   2.03226844e-02
#    -8.20045277e-03   1.14755227e-02  -1.41370196e-02   1.14491149e-02
#    -6.43082659e-04   7.30331269e-03  -2.00580879e-02  -2.43144769e-02]]
# New betas:
# [[ 4.87467944]
#  [ 0.04765051]
#  [-0.1671237 ]
#  [ 0.04500083]
#  [ 0.02702161]
#  [-0.08056319]
#  [ 0.0162884 ]
#  [-0.08613716]
#  [-0.08078219]
#  [-0.01965285]
#  [ 0.13630834]
#  [ 0.24285023]]
#
#
# Cost in iteraction 19: 0.500391160165
# Error convergence: 0.0681897149956
# Derivatives: [[-0.76134307 -0.00727098  0.0084646   0.0204157  -0.00742069  0.01033751
#   -0.0134413   0.01076638 -0.00154619  0.00741791 -0.01830947 -0.02152373]]
# New betas:
# [[ 4.95081375]
#  [ 0.04837761]
#  [-0.16797016]
#  [ 0.04295926]
#  [ 0.02776368]
#  [-0.08159694]
#  [ 0.01763253]
#  [-0.0872138 ]
#  [-0.08062757]
#  [-0.02039464]
#  [ 0.13813929]
#  [ 0.24500261]]
#
#
# Cost in iteraction 20: 0.445145576421
# Error convergence: 0.0552455837434
# Derivatives: [[-0.68520876 -0.00698289  0.00731807  0.02037347 -0.00669587  0.00933362
#   -0.01277222  0.01016598 -0.00226167  0.00749326 -0.01675027 -0.01914078]]
# New betas:
# [[ 5.01933463]
#  [ 0.0490759 ]
#  [-0.16870197]
#  [ 0.04092192]
#  [ 0.02843327]
#  [-0.0825303 ]
#  [ 0.01890975]
#  [-0.0882304 ]
#  [-0.0804014 ]
#  [-0.02114397]
#  [ 0.13981431]
#  [ 0.24691669]]
#
#
# Cost in iteraction 21: 0.400384572506
# Error convergence: 0.0447610039149
# Derivatives: [[-0.61668789 -0.00670644  0.00639112  0.02022434 -0.00602554  0.00844485
#   -0.01213359  0.00963103 -0.00282309  0.00753354 -0.01535497 -0.01710145]]
# New betas:
# [[ 5.08100342]
#  [ 0.04974654]
#  [-0.16934108]
#  [ 0.03889948]
#  [ 0.02903582]
#  [-0.08337479]
#  [ 0.02012311]
#  [-0.0891935 ]
#  [-0.0801191 ]
#  [-0.02189732]
#  [ 0.14134981]
#  [ 0.24862683]]
#
#
# Cost in iteraction 22: 0.364116232952
# Error convergence: 0.0362683395543
# Derivatives: [[-0.5550191  -0.00643965  0.00564363  0.01999129 -0.00540827  0.00765509
#   -0.01152733  0.00914848 -0.00325835  0.00754284 -0.01410203 -0.01535207]]
# New betas:
# [[ 5.13650533]
#  [ 0.05039051]
#  [-0.16990544]
#  [ 0.03690035]
#  [ 0.02957665]
#  [-0.0841403 ]
#  [ 0.02127584]
#  [-0.09010835]
#  [-0.07979326]
#  [-0.02265161]
#  [ 0.14276001]
#  [ 0.25016204]]
#
#
# Cost in iteraction 23: 0.33472730692
# Error convergence: 0.029388926032
# Derivatives: [[-0.49951719 -0.00618128  0.00504263  0.01969299 -0.00484193  0.00695076
#   -0.01095402  0.00870821 -0.00359063  0.00752505 -0.01297321 -0.01384768]]
# New betas:
# [[ 5.18645705]
#  [ 0.05100864]
#  [-0.17040971]
#  [ 0.03493105]
#  [ 0.03006084]
#  [-0.08483537]
#  [ 0.02237124]
#  [-0.09097917]
#  [-0.0794342 ]
#  [-0.02340411]
#  [ 0.14405733]
#  [ 0.2515468 ]]
#
#
# Cost in iteraction 24: 0.31091118076
# Error convergence: 0.0238161261597
# Derivatives: [[-0.44956547 -0.00593057  0.00456101  0.01934459 -0.00432393  0.00632033
#   -0.01041329  0.00830242 -0.00383911  0.00748379 -0.01195302 -0.0125506 ]]
# New betas:
# [[ 5.23141359]
#  [ 0.05160169]
#  [-0.17086581]
#  [ 0.0329966 ]
#  [ 0.03049324]
#  [-0.08546741]
#  [ 0.02341257]
#  [-0.09180941]
#  [-0.07905029]
#  [-0.02415249]
#  [ 0.14525264]
#  [ 0.25280187]]
#
#
# Cost in iteraction 25: 0.291609562592
# Error convergence: 0.0193016181684
# Derivatives: [[-0.40460892 -0.00568706  0.00417648  0.01895843 -0.0038514   0.00575405
#   -0.00990416  0.00792512 -0.00401963  0.00742235 -0.01102825 -0.01142924]]
# New betas:
# [[ 5.27187448]
#  [ 0.0521704 ]
#  [-0.17128345]
#  [ 0.03110075]
#  [ 0.03087838]
#  [-0.08604281]
#  [ 0.02440299]
#  [-0.09260192]
#  [-0.07864832]
#  [-0.02489473]
#  [ 0.14635546]
#  [ 0.25394479]]
#
#
# Cost in iteraction 26: 0.275965265088
# Error convergence: 0.0156442975043
# Derivatives: [[-0.36414803 -0.0054505   0.00387072  0.01854452 -0.00342133  0.00524365
#   -0.00942523  0.00757167 -0.00414527  0.00734371 -0.01018758 -0.01045703]]
# New betas:
# [[ 5.30828929]
#  [ 0.05271545]
#  [-0.17167053]
#  [ 0.0292463 ]
#  [ 0.03122051]
#  [-0.08656718]
#  [ 0.02534551]
#  [-0.09335909]
#  [-0.0782338 ]
#  [-0.0256291 ]
#  [ 0.14737422]
#  [ 0.25499049]]
#
#
# Cost in iteraction 27: 0.263283971981
# Error convergence: 0.0126812931067
# Derivatives: [[-0.32773323 -0.00522079  0.00362867  0.01811098 -0.00303067  0.00478209
#   -0.00897485  0.0072385  -0.00422681  0.00725053 -0.00942132 -0.00961167]]
# New betas:
# [[ 5.34106261]
#  [ 0.05323753]
#  [-0.17203339]
#  [ 0.0274352 ]
#  [ 0.03152358]
#  [-0.08704539]
#  [ 0.026243  ]
#  [-0.09408294]
#  [-0.07781112]
#  [-0.02635415]
#  [ 0.14831635]
#  [ 0.25595166]]
#
#
# Cost in iteraction 28: 0.253003277405
# Error convergence: 0.0102806945758
# Derivatives: [[-0.2949599  -0.00499785  0.00343796  0.01766439 -0.00267639  0.0043634
#   -0.00855129  0.00692287 -0.00427307  0.00714519 -0.00872112 -0.00887437]]
# New betas:
# [[ 5.3705586 ]
#  [ 0.05373731]
#  [-0.17237719]
#  [ 0.02566876]
#  [ 0.03179122]
#  [-0.08748173]
#  [ 0.02709813]
#  [-0.09477523]
#  [-0.07738381]
#  [-0.02706867]
#  [ 0.14918846]
#  [ 0.2568391 ]]
#
#
# Cost in iteraction 29: 0.244667613503
# Error convergence: 0.00833566390203
# Derivatives: [[-0.26546391 -0.00478165  0.00328846  0.01721008 -0.00235556  0.00398247
#   -0.00815274  0.00662266 -0.00429133  0.00702978 -0.00807975 -0.0082293 ]]
# New betas:
# [[ 5.39710499]
#  [ 0.05421548]
#  [-0.17270604]
#  [ 0.02394776]
#  [ 0.03202677]
#  [-0.08787997]
#  [ 0.0279134 ]
#  [-0.09543749]
#  [-0.07695468]
#  [-0.02777165]
#  [ 0.14999644]
#  [ 0.25766203]]
#
#
# Cost in iteraction 30: 0.23790794567
# Error convergence: 0.00675966783278
# Derivatives: [[-0.23891752 -0.00457219  0.00317186  0.01675235 -0.00206537  0.00363494
#   -0.00777744  0.00633622 -0.00428751  0.00690615 -0.00749098 -0.00766311]]
# New betas:
# [[ 5.42099674]
#  [ 0.0546727 ]
#  [-0.17302322]
#  [ 0.02227252]
#  [ 0.03223331]
#  [-0.08824347]
#  [ 0.02869114]
#  [-0.09607111]
#  [-0.07652592]
#  [-0.02846226]
#  [ 0.15074554]
#  [ 0.25842834]]
#
#
# Cost in iteraction 31: 0.232425328303
# Error convergence: 0.00548261736715
# Derivatives: [[-0.21502577 -0.00436944  0.00308134  0.01629462 -0.00180317  0.00331708
#   -0.00742369  0.00606227 -0.00426646  0.00677592 -0.00694937 -0.0071645 ]]
# New betas:
# [[ 5.44249932]
#  [ 0.05510964]
#  [-0.17333136]
#  [ 0.02064306]
#  [ 0.03241363]
#  [-0.08857518]
#  [ 0.02943351]
#  [-0.09667734]
#  [-0.07609928]
#  [-0.02913985]
#  [ 0.15144047]
#  [ 0.25914479]]
#
#
# Cost in iteraction 32: 0.227977586681
# Error convergence: 0.00444774162171
# Derivatives: [[-0.19352319 -0.00417336  0.00301137  0.01583964 -0.00156646  0.00302565
#   -0.00708989  0.0057998  -0.00423213  0.00664052 -0.00645019 -0.00672392]]
# New betas:
# [[ 5.46185164]
#  [ 0.05552698]
#  [-0.17363249]
#  [ 0.0190591 ]
#  [ 0.03257027]
#  [-0.08887774]
#  [ 0.0301425 ]
#  [-0.09725732]
#  [-0.07567607]
#  [-0.02980391]
#  [ 0.15208549]
#  [ 0.25981718]]
#
#
# Cost in iteraction 33: 0.224368530421
# Error convergence: 0.00360905625995
# Derivatives: [[-0.17417087 -0.0039839   0.00295742  0.01538958 -0.00135291  0.00275789
#   -0.00677452  0.005548   -0.00418772  0.00650118 -0.00598929 -0.00633328]]
# New betas:
# [[ 5.47926873]
#  [ 0.05592537]
#  [-0.17392824]
#  [ 0.01752014]
#  [ 0.03270556]
#  [-0.08915353]
#  [ 0.03081995]
#  [-0.09781212]
#  [-0.07525729]
#  [-0.03045402]
#  [ 0.15268442]
#  [ 0.26045051]]
#
#
# Cost in iteraction 34: 0.221439217093
# Error convergence: 0.0029293133284
# Derivatives: [[-0.15675379 -0.00380098  0.0029158   0.01494615 -0.00116038  0.0025114
#   -0.00647618  0.00530622 -0.00413581  0.00635898 -0.00556304 -0.0059857 ]]
# New betas:
# [[ 5.49494411]
#  [ 0.05630547]
#  [-0.17421982]
#  [ 0.01602552]
#  [ 0.0328216 ]
#  [-0.08940467]
#  [ 0.03146757]
#  [-0.09834274]
#  [-0.07484371]
#  [-0.03108992]
#  [ 0.15324073]
#  [ 0.26104908]]
#
#
# Cost in iteraction 35: 0.219060876192
# Error convergence: 0.00237834090144
# Derivatives: [[-0.14107841 -0.00362452  0.00288355  0.01451066 -0.00098687  0.00228409
#   -0.00619361  0.00507392 -0.00407851  0.00621485 -0.00516824 -0.00567536]]
# New betas:
# [[ 5.50905195]
#  [ 0.05666792]
#  [-0.17450817]
#  [ 0.01457446]
#  [ 0.03292029]
#  [-0.08963308]
#  [ 0.03208693]
#  [-0.09885014]
#  [-0.07443586]
#  [-0.03171141]
#  [ 0.15375755]
#  [ 0.26161661]]
#
#
# Cost in iteraction 36: 0.21712917781
# Error convergence: 0.00193169838115
# Derivatives: [[-0.12697057 -0.0034544   0.00285825  0.0140841  -0.00083057  0.00207413
#   -0.00592561  0.00485064 -0.00401748  0.00606963 -0.00480205 -0.00539727]]
# New betas:
# [[ 5.521749  ]
#  [ 0.05701336]
#  [-0.174794  ]
#  [ 0.01316605]
#  [ 0.03300334]
#  [-0.08984049]
#  [ 0.03267949]
#  [-0.0993352 ]
#  [-0.07403411]
#  [-0.03231837]
#  [ 0.15423776]
#  [ 0.26215634]]
#
#
# Cost in iteraction 37: 0.215559590394
# Error convergence: 0.00156958741607
# Derivatives: [[-0.11427351 -0.00329049  0.00283797  0.01366723 -0.00068981  0.00187993
#   -0.00567111  0.00463599 -0.00395406  0.00592399 -0.00446199 -0.00514719]]
# New betas:
# [[ 5.53317635]
#  [ 0.05734241]
#  [-0.17507779]
#  [ 0.01179932]
#  [ 0.03307232]
#  [-0.09002849]
#  [ 0.0332466 ]
#  [-0.0997988 ]
#  [-0.07363871]
#  [-0.03291077]
#  [ 0.15468395]
#  [ 0.26267106]]
#
#
# Cost in iteraction 38: 0.214283620566
# Error convergence: 0.00127596982863
# Derivatives: [[-0.10284616 -0.00313267  0.00282117  0.01326056 -0.00056307  0.0017001
#   -0.00542916  0.00442963 -0.00388931  0.00577855 -0.00414581 -0.00492149]]
# New betas:
# [[ 5.54346097]
#  [ 0.05765567]
#  [-0.17535991]
#  [ 0.01047327]
#  [ 0.03312863]
#  [-0.0901985 ]
#  [ 0.03378952]
#  [-0.10024176]
#  [-0.07324978]
#  [-0.03348862]
#  [ 0.15509854]
#  [ 0.26316321]]
#
#
# Cost in iteraction 39: 0.213245767375
# Error convergence: 0.00103785319064
# Derivatives: [[-0.09256154 -0.00298078  0.00280663  0.01286447 -0.00044897  0.00153339
#   -0.00519885  0.00423124 -0.00382406  0.00563382 -0.00385153 -0.00471708]]
# New betas:
# [[ 5.55271713]
#  [ 0.05795375]
#  [-0.17564057]
#  [ 0.00918682]
#  [ 0.03317353]
#  [-0.09035184]
#  [ 0.0343094 ]
#  [-0.10066489]
#  [-0.07286737]
#  [-0.03405201]
#  [ 0.15548369]
#  [ 0.26363491]]
#
#
# Cost in iteraction 40: 0.212401055201
# Error convergence: 0.000844712173668
# Derivatives: [[-0.08330539 -0.00283466  0.00279338  0.01247917 -0.00034626  0.00137871
#   -0.0049794   0.00404053 -0.00375896  0.00549025 -0.00357738 -0.00453129]]
# New betas:
# [[ 5.56104766]
#  [ 0.05823722]
#  [-0.17591991]
#  [ 0.0079389 ]
#  [ 0.03320815]
#  [-0.09048971]
#  [ 0.03480734]
#  [-0.10106894]
#  [-0.07249147]
#  [-0.03460103]
#  [ 0.15584143]
#  [ 0.26408804]]
#
#
# Cost in iteraction 41: 0.211713035338
# Error convergence: 0.000688019863611
# Derivatives: [[-0.07497485 -0.00269415  0.00278066  0.01210477 -0.00025381  0.00123509
#   -0.00477008  0.00385723 -0.0036945   0.00534821 -0.00332177 -0.00436184]]
# New betas:
# [[ 5.56854515]
#  [ 0.05850663]
#  [-0.17619798]
#  [ 0.00672843]
#  [ 0.03323354]
#  [-0.09061322]
#  [ 0.03528435]
#  [-0.10145466]
#  [-0.07212202]
#  [-0.03513585]
#  [ 0.1561736 ]
#  [ 0.26452423]]
#
#
# Cost in iteraction 42: 0.211152167201
# Error convergence: 0.000560868137017
# Derivatives: [[-0.06747737 -0.00255907  0.00276791  0.01174128 -0.00017059  0.00110166
#   -0.00457023  0.00368109 -0.00363106  0.00520801 -0.00308324 -0.00420676]]
# New betas:
# [[  5.57529289e+00]
#  [  5.87625399e-02]
#  [ -1.76474768e-01]
#  [  5.55429859e-03]
#  [  3.32505944e-02]
#  [ -9.07233815e-02]
#  [  3.57413761e-02]
#  [ -1.01822771e-01]
#  [ -7.17589163e-02]
#  [ -3.56566521e-02]
#  [  1.56481928e-01]
#  [  2.64944904e-01]]
#
#
# Cost in iteraction 43: 0.210694507029
# Error convergence: 0.000457660171393
# Derivatives: [[ -6.07296286e-02  -2.42925296e-03   2.75469123e-03   1.13886418e-02
#    -9.56736957e-05   9.77626433e-04  -4.37927176e-03   3.51185099e-03
#    -3.56892055e-03   5.06993227e-03  -2.86051117e-03  -4.06434168e-03]]
# New betas:
# [[  5.58136585e+00]
#  [  5.90054652e-02]
#  [ -1.76750237e-01]
#  [  4.41543440e-03]
#  [  3.32601618e-02]
#  [ -9.08211442e-02]
#  [  3.61793033e-02]
#  [ -1.02173956e-01]
#  [ -7.14020243e-02]
#  [ -3.61636453e-02]
#  [  1.56767979e-01]
#  [  2.65351338e-01]]
#
#
# Cost in iteraction 44: 0.21032064565
# Error convergence: 0.000373861379917
# Derivatives: [[ -5.46566657e-02  -2.30452335e-03   2.74067550e-03   1.10467507e-02
#    -2.82276861e-05   8.62299512e-04  -4.19665521e-03   3.34928631e-03
#    -3.50827309e-03   4.93418590e-03  -2.65240510e-03  -3.93312656e-03]]
# New betas:
# [[  5.58683151e+00]
#  [  5.92359176e-02]
#  [ -1.77024304e-01]
#  [  3.31075933e-03]
#  [  3.32629845e-02]
#  [ -9.09073741e-02]
#  [  3.65989688e-02]
#  [ -1.02508884e-01]
#  [ -7.10511970e-02]
#  [ -3.66570639e-02]
#  [  1.57033219e-01]
#  [  2.65744651e-01]]
#
#
# Cost in iteraction 45: 0.210014847982
# Error convergence: 0.000305797667352
# Derivatives: [[ -4.91909992e-02  -2.18470451e-03   2.72563752e-03   1.07154426e-02
#     3.24992849e-05   7.55040942e-04  -4.02189601e-03   3.19316228e-03
#    -3.44925517e-03   4.80095493e-03  -2.45785525e-03  -3.81184058e-03]]
# New betas:
# [[  5.59175061e+00]
#  [  5.94543880e-02]
#  [ -1.77296868e-01]
#  [  2.23921507e-03]
#  [  3.32597346e-02]
#  [ -9.09828782e-02]
#  [  3.70011584e-02]
#  [ -1.02828201e-01]
#  [ -7.07062715e-02]
#  [ -3.71371594e-02]
#  [  1.57279005e-01]
#  [  2.66125835e-01]]
#
#
# Cost in iteraction 46: 0.209764355968
# Error convergence: 0.000250492014485
# Derivatives: [[ -4.42718993e-02  -2.06962144e-03   2.70942271e-03   1.03945227e-02
#     8.71833609e-05   6.55275103e-04  -3.85454976e-03   3.04325475e-03
#    -3.39195139e-03   4.67038617e-03  -2.27589073e-03  -3.69937988e-03]]
# New betas:
# [[  5.59617780e+00]
#  [  5.96613502e-02]
#  [ -1.77567810e-01]
#  [  1.19976279e-03]
#  [  3.32510163e-02]
#  [ -9.10484057e-02]
#  [  3.73866134e-02]
#  [ -1.03132526e-01]
#  [ -7.03670763e-02]
#  [ -3.76041980e-02]
#  [  1.57506594e-01]
#  [  2.66495773e-01]]
#
#
# Cost in iteraction 47: 0.20955882386
# Error convergence: 0.000205532107724
# Derivatives: [[-0.03984471 -0.0019591   0.00269194  0.01008377  0.00013643  0.00056248
#   -0.00369421  0.00289935 -0.00333641  0.0045426  -0.00210563 -0.00359478]]
# New betas:
# [[  5.60016228e+00]
#  [  5.98572602e-02]
#  [ -1.77837004e-01]
#  [  1.91385819e-04]
#  [  3.32373730e-02]
#  [ -9.11046535e-02]
#  [  3.77560345e-02]
#  [ -1.03422461e-01]
#  [ -7.00334357e-02]
#  [ -3.80584576e-02]
#  [  1.57717157e-01]
#  [  2.66855251e-01]]
#
#
# Cost in iteraction 48: 0.209389860745
# Error convergence: 0.000168963114748
# Derivatives: [[-0.03586024 -0.00185297  0.00267313  0.00978294  0.00018079  0.00047617
#   -0.00354051  0.00276122 -0.00328264  0.00441768 -0.00194625 -0.00349722]]
# New betas:
# [[  5.60374830e+00]
#  [  6.00425574e-02]
#  [ -1.78104317e-01]
#  [ -7.86908419e-04]
#  [  3.32192938e-02]
#  [ -9.11522707e-02]
#  [  3.81100854e-02]
#  [ -1.03698583e-01]
#  [ -6.97051722e-02]
#  [ -3.85002251e-02]
#  [  1.57911781e-01]
#  [  2.67204973e-01]]
#
#
# Cost in iteraction 49: 0.209250659917
# Error convergence: 0.000139200828259
# Derivatives: [[-0.03227421 -0.00175107  0.00265299  0.00949179  0.00022075  0.00039592
#   -0.0033931   0.00262867 -0.00323063  0.00429569 -0.00179702 -0.00340595]]
# New betas:
# [[  5.60697572e+00]
#  [  6.02176642e-02]
#  [ -1.78369615e-01]
#  [ -1.73608692e-03]
#  [  3.31972183e-02]
#  [ -9.11918626e-02]
#  [  3.84493958e-02]
#  [ -1.03961450e-01]
#  [ -6.93821095e-02]
#  [ -3.89297942e-02]
#  [  1.58091483e-01]
#  [  2.67545568e-01]]
#
#
# Cost in iteraction 50: 0.209135698609
# Error convergence: 0.000114961307882
# Derivatives: [[-0.02904679 -0.00165322  0.00263153  0.00921003  0.00025676  0.00032132
#   -0.00325168  0.0025015  -0.00318035  0.00417669 -0.00165725 -0.00332033]]
# New betas:
# [[  5.60988040e+00]
#  [  6.03829865e-02]
#  [ -1.78632768e-01]
#  [ -2.65709018e-03]
#  [  3.31715424e-02]
#  [ -9.12239941e-02]
#  [  3.87745641e-02]
#  [ -1.04211600e-01]
#  [ -6.90640743e-02]
#  [ -3.93474631e-02]
#  [  1.58257208e-01]
#  [  2.67877601e-01]]
#
#
# Cost in iteraction 51: 0.209040494723
# Error convergence: 9.52038856642e-05
# Derivatives: [[-0.02614211 -0.00155928  0.00260879  0.00893741  0.0002892   0.00025199
#   -0.00311596  0.00237951 -0.00313177  0.0040607  -0.00152631 -0.00323981]]
# New betas:
# [[  5.61249461e+00]
#  [  6.05389145e-02]
#  [ -1.78893648e-01]
#  [ -3.55083155e-03]
#  [  3.31426225e-02]
#  [ -9.12491934e-02]
#  [  3.90861598e-02]
#  [ -1.04449551e-01]
#  [ -6.87508972e-02]
#  [ -3.97535331e-02]
#  [  1.58409838e-01]
#  [  2.68201581e-01]]

# %% [markdown]
# ### Compare final error and betas - Very different betas, why?

# %%
print('Error in the non normalized data: ' + str(errorArray[errorArray != 0][-1]))
print('\n')
print('Error in the normalized data: ' + str(errorArray_norm[errorArray_norm != 0][-1]))

print('\n')

print(betas)
print('\n')
print(betas_norm)
# Out:
# Error in the non normalized data: 0.292496329629
#
#
# Error in the normalized data: 0.209040494723
#
#
# [[ 0.02683478]
#  [ 0.21517302]
#  [ 0.01195216]
#  [ 0.00701258]
#  [ 0.04898523]
#  [ 0.00208199]
#  [ 0.02651465]
#  [-0.00454669]
#  [ 0.02672011]
#  [ 0.08959919]
#  [ 0.01858011]
#  [ 0.29509982]]
#
#
# [[  5.61249461e+00]
#  [  6.05389145e-02]
#  [ -1.78893648e-01]
#  [ -3.55083155e-03]
#  [  3.31426225e-02]
#  [ -9.12491934e-02]
#  [  3.90861598e-02]
#  [ -1.04449551e-01]
#  [ -6.87508972e-02]
#  [ -3.97535331e-02]
#  [  1.58409838e-01]
#  [  2.68201581e-01]]

# %% [markdown]
# ### Try analytical approach - Normal Equations
#
# Equation comes from deriving the cost function J(theta) in relation to theta. Link for the derivation: [link](http://eli.thegreenplace.net/2014/derivation-of-the-normal-equation-for-linear-regression)
#
# $$\theta = (X^TX)^{-1}X^TY$$

# %%
betas_normal = np.matmul(
                   np.linalg.inv(
                       np.matmul(
                           np.transpose(x_data_norm), x_data_norm)
                       ),
                   np.matmul(np.transpose(x_data_norm), y_data)
                )
betas_normal
# Out:
# matrix([[ 5.63602251],
#         [ 0.04351096],
#         [-0.19402735],
#         [-0.03556366],
#         [ 0.02302592],
#         [-0.08821097],
#         [ 0.04562023],
#         [-0.10738941],
#         [-0.03374773],
#         [-0.06386245],
#         [ 0.15532508],
#         [ 0.29433493]])

# %% [markdown]
# ### Get error for betas_normal

# %%
predictedValues = np.matrix(x_data_norm * betas_normal)

calculateError(predictedValues, y_data)
# Out:
# 0.20838358361070397
